# %% [markdown]
# # Usage of External Dataset

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Change directory if needed
# !cd "/content/drive/My Drive/OCRTraining"

# Check directory
# !ls "/content/drive/My Drive/OCRTraining/PassportDataset/"
# Out:
# Mounted at /content/drive
# dejavu-fonts-ttf-2.37  extract	mutated_passports    patrick_hand_font	  test
# DejaVuSans-Bold.ttf    img	original_annotation  synthetic_passports  train

# %% [markdown]
# # Usage of Labelme for Annotation

# %%
# !pip install -U labelme2coco
# Out:
# Requirement already satisfied: labelme2coco in /usr/local/lib/python3.10/dist-packages (0.2.6)
# Requirement already satisfied: sahi>=0.8.19 in /usr/local/lib/python3.10/dist-packages (from labelme2coco) (0.11.19)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from labelme2coco) (4.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco) (0.22.3)
# Requirement already satisfied: opencv-python<=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco) (4.9.0.80)
# Requirement already satisfied: shapely>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco) (2.0.6)
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco) (4.66.6)
# Requirement already satisfied: pillow>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco) (10.2.0)
# Requirement already satisfied: pybboxes==0.1.6 in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco) (0.1.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco) (6.0.2)
# Requirement already satisfied: fire in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco) (0.7.0)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco) (3.1.10)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco) (2.32.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco) (8.1.7)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco) (1.26.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->sahi>=0.8.19->labelme2coco) (2.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (2024.8.30)

# %%
# !labelme
# Out:
# /bin/bash: line 1: labelme: command not found

# %% [markdown]
# # Split Train and Test
# For Indian Passport Dataset

# %%
# Imports
import os
import random
import shutil

# File paths
dataset_path = "/content/drive/My Drive/OCRTraining/PassportDataset"
images_folder = os.path.join(dataset_path, "mutated_passports")  # Base path to mutated image folder
extracted_annotation_path = os.path.join(dataset_path, "synthetic_passports/labels.txt")  # Image_Path|Fields
train_folder = os.path.join(dataset_path, "train")
test_folder = os.path.join(dataset_path, "test")
train_folder_img = os.path.join(train_folder, "images")
test_folder_img = os.path.join(test_folder, "images")
train_annotation_txt = os.path.join(train_folder, "train_annotation.txt")
test_annotation_txt = os.path.join(test_folder, "test_annotation.txt")

# Ensure output folders exist
os.makedirs(train_folder_img, exist_ok=True)
os.makedirs(test_folder_img, exist_ok=True)

# Load annotations
with open(extracted_annotation_path, 'r') as f:
    annotations = f.readlines()

# Debug: Check the first few lines of annotations
print("First few lines of labels.txt:")
for i, line in enumerate(annotations[:5]):
    print(f"Line {i+1}: {line.strip()}")

# Skip the header
annotations = annotations[1:]  # Remove the header: "Image_Path|Fields"

# Shuffle the annotations randomly
random.shuffle(annotations)

# Split annotations: 80% train, 20% test
split_index = int(0.8 * len(annotations))
train_annotations = annotations[:split_index]
test_annotations = annotations[split_index:]

# Function to move images and update annotations with their new paths
def move_images_and_update_annotations(annotations, src_folder, dest_folder_img):
    updated_annotations = []
    for line in annotations:
        line_parts = line.strip().split("|")
        if len(line_parts) != 2:
            print(f"Skipping invalid annotation line: {line.strip()}")
            continue

        img_file = os.path.basename(line_parts[0])  # Extract image file name
        label = line_parts[1]  # Extract JSON string for fields
        src_path = os.path.join(src_folder, img_file)
        dest_path = os.path.join(dest_folder_img, img_file)

        if os.path.exists(src_path):  # Check if the source file exists
            shutil.copy(src_path, dest_path)  # Move image to destination
            '''
            Update the path in the annotation to point to the new end folder, for instance:
            From:
            /content/drive/My Drive/OCRTraining/PassportDataset/synthetic_passports/passport_1.jpg | {"fullname": "John Doe", "nationality": "USA", ...}
            To:
            /content/drive/My Drive/OCRTraining/PassportDataset/mutated_passports/passport_1.jpg | {"fullname": "John Doe", "nationality": "USA", ...}
            '''
            updated_annotations.append(f"{dest_path}\t{label}\n")
        else:
            print(f"Warning: File not found: {src_path}")
    return updated_annotations

# Move images and update train and test annotations
train_annotations_updated = move_images_and_update_annotations(train_annotations, images_folder, train_folder_img)
test_annotations_updated = move_images_and_update_annotations(test_annotations, images_folder, test_folder_img)

# Write and save updated train and test annotation files
with open(train_annotation_txt, 'w') as f:
    f.writelines(train_annotations_updated)

with open(test_annotation_txt, 'w') as f:
    f.writelines(test_annotations_updated)

print(f"Dataset split completed:")
print(f"Train dataset: {len(train_annotations_updated)} images")
print(f"Test dataset: {len(test_annotations_updated)} images")
# Out:
# First few lines of labels.txt:
# Line 1: Image_Path|Fields
# Line 2: /content/drive/My Drive/OCRTraining/PassportDataset/synthetic_passports/vpassport_284.jpg|{"fullname": "\u00f2Bo\u1ee4hy\u0110h\u1eb2\u1ed7rB", "nationality": "q\u1ef5O\u1ec6\u1edb\u0168aA", "pob": "\u00d2\u1ed9IdtOAexWB\u00c1\u0129\u1eed\u1ec4", "dob": "31/10/1967", "sex": "N\u1eef/F", "cmnd": "328219921", "passportid": "C7242158", "nameid": "VNM\u00d2BO\u1ee4HY\u0110H\u1eb2\u1ed6RB<", "passportid2": "C7242158"}
# Line 3: /content/drive/My Drive/OCRTraining/PassportDataset/synthetic_passports/vpassport_378.jpg|{"fullname": "GX\u1ec5\u00d2\u1ef2\u1ea4a\u1eb5m\u00da\u01b0s", "nationality": "G\u1eb8u\u1ebb\u1ea9\u1eef\u00e8Q", "pob": "u\u1ef0Sx\u1edat\u1ec9\u1eb5\u1ec1\u1ec8\u1ee8qfW\u00e0", "dob": "31/10/1967", "sex": "N\u1eef/F", "cmnd": "404436753", "passportid": "N9063181", "nameid": "VNMGX\u1ec4\u00d2\u1ef2\u1ea4A\u1eb4M\u00da\u01afS<", "passportid2": "N9063181"}
# Line 4: /content/drive/My Drive/OCRTraining/PassportDataset/synthetic_passports/vpassport_660.jpg|{"fullname": "l\u1eb5\u1eca\u00fa\u1eda\u1edb\u1ef2\u00ed\u1ef5\u00f2j\u00e0", "nationality": "HN\u1ec8\u0103f\u01afH\u0129", "pob": "\u1eea\u00d5\u1ed5\u1ea6\u1ee2Ow\u1ee9\u1ecb\u1ea9\u00e1\u1ef8G\u1ea9\u00c9", "dob": "31/10/1967", "sex": "N\u1eef/F", "cmnd": "820363239", "passportid": "V2268958", "nameid": "VNML\u1eb4\u1eca\u00da\u1eda\u1eda\u1ef2\u00cd\u1ef4\u00d2J\u00c0<", "passportid2": "V2268958"}
# Line 5: /content/drive/My Drive/OCRTraining/PassportDataset/synthetic_passports/vpassport_2.jpg|{"fullname": "\u1ec3\u1eb2R\u0168\u00fa\u1ecd\u1ea8\u1ec3X\u00cae\u01af", "nationality": "\u1ecc\u0168\u0110\u1ecf\u1ed0c\u00dd\u1ef0", "pob": "\u1ed0B\u1ed1L\u1eed\u1ed5\u1ede\u1ef5\u0168m\u0102\u1eb2\u00f5Bc", "dob": "31/10/1967", "sex": "Nam/M", "cmnd": "186911969", "passportid": "L3673590", "nameid": "VNM\u1ec2\u1eb2R\u0168\u00da\u1ecc\u1ea8\u1ec2X\u00caE\u01af<", "passportid2": "L3673590"}
# Skipping invalid annotation line: 8"}
# Skipping invalid annotation line: 13"}
# Dataset split completed:
# Train dataset: 2395 images
# Test dataset: 600 images

# %% [markdown]
# # Data Box Labelling from Original Template
# For Indian Passport Dataset

# %%
import os
import json
import cv2

# Paths
dataset_path = "/content/drive/My Drive/OCRTraining/PassportDataset"
image_folder = os.path.join(dataset_path, "train/images")
label_folder = os.path.join(dataset_path, "train/labels")
template_json_path = os.path.join(dataset_path, "synthetic_passports/template/passport_template.json")
os.makedirs(label_folder, exist_ok=True)

# YOLO class mapping
classes = {
    "fullname": 0,
    "nationality": 1,
    "dob": 2,
    "sex": 3,
    "pob": 4,
    "cmnd": 5,
    "passportid": 6,
    "nameid": 7,
    "passportid2": 8
}

# Convert polygon points to YOLO format
def convert_to_yolo(points, img_width, img_height):
    x_coords = [p[0] for p in points]
    y_coords = [p[1] for p in points]
    x_min, x_max = min(x_coords), max(x_coords)
    y_min, y_max = min(y_coords), max(y_coords)
    x_center = (x_min + x_max) / 2 / img_width
    y_center = (y_min + y_max) / 2 / img_height
    bbox_width = (x_max - x_min) / img_width
    bbox_height = (y_max - y_min) / img_height
    return x_center, y_center, bbox_width, bbox_height

# Draw bounding boxes for debug images
def draw_bounding_boxes(img, points, label_name, color=(0, 255, 0)):
    x_coords = [p[0] for p in points]
    y_coords = [p[1] for p in points]
    x_min, x_max = int(min(x_coords)), int(max(x_coords))
    y_min, y_max = int(min(y_coords)), int(max(y_coords))
    cv2.rectangle(img, (x_min, y_min), (x_max, y_max), color, 2)
    cv2.putText(img, label_name, (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

# Generate label files for all images using the template
# Write label YOLO format: <object_class> <x_center> <y_center> <width> <height>
def generate_labels_from_template(image_folder, label_folder, template_json_path):
    # Load template JSON
    with open(template_json_path, "r") as f:
        template_data = json.load(f)

    #  Make sure the image is in a correct extension format
    shapes = template_data["shapes"]  # Get field shapes
    for img_file in os.listdir(image_folder):
        if not img_file.endswith(".jpg"):
            continue

        # Define input and output paths
        image_path = os.path.join(image_folder, img_file)
        label_path = os.path.join(label_folder, f"{os.path.splitext(img_file)[0]}.txt")
        debug_image_path = os.path.join(label_folder, f"{os.path.splitext(img_file)[0]}_debug.jpg")

        # Read the image to get dimensions
        img = cv2.imread(image_path)
        if img is None:
            print(f"Error: Could not load {image_path}. Skipping.")
            continue
        img_height, img_width = img.shape[:2]

        # Init empty labels array lists that we can later add in data
        labels = []
        for shape in shapes:
            label_name = shape["label"]
            points = shape["points"]

            # Hardly happens but a checker to ensure the class labelled is valid
            if label_name not in classes:
                print(f"Warning: {label_name} is not in class mapping. Skipping.")
                continue

            # Mapping the YOLO coordination format label file with corresponding to the class id of that image
            class_id = classes[label_name]
            x_center, y_center, bbox_width, bbox_height = convert_to_yolo(points, img_width, img_height)
            labels.append(f"{class_id} {x_center:.6f} {y_center:.6f} {bbox_width:.6f} {bbox_height:.6f}")

            # Draw bounding boxes for debugging (draw surround that field by coordinated pts, and the label name or class)
            draw_bounding_boxes(img, points, label_name)

        # Save labels to file
        with open(label_path, "w") as f:
            f.write("\n".join(labels))
        print(f"Saved labels for {img_file} to {label_path}")

        # Save the debug image
        cv2.imwrite(debug_image_path, img)
        print(f"Saved debug image to {debug_image_path}")

# Main script
if __name__ == "__main__":
    generate_labels_from_template(image_folder, label_folder, template_json_path)
    print("Label generation complete!")
# Out:
# Saved labels for vpassport_1219.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1219.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1219_debug.jpg
# Saved labels for vpassport_688.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_688.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_688_debug.jpg
# Saved labels for vpassport_2666.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2666.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2666_debug.jpg
# Saved labels for vpassport_1138.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1138.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1138_debug.jpg
# Saved labels for vpassport_1907.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1907.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1907_debug.jpg
# Saved labels for vpassport_814.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_814.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_814_debug.jpg
# Saved labels for vpassport_532.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_532.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_532_debug.jpg
# Saved labels for vpassport_734.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_734.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_734_debug.jpg
# Saved labels for vpassport_1555.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1555.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1555_debug.jpg
# Saved labels for vpassport_1149.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1149.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1149_debug.jpg
# Saved labels for vpassport_678.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_678.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_678_debug.jpg
# Saved labels for vpassport_794.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_794.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_794_debug.jpg
# Saved labels for vpassport_258.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_258.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_258_debug.jpg
# Saved labels for vpassport_1605.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1605.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1605_debug.jpg
# Saved labels for vpassport_1767.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1767.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1767_debug.jpg
# Saved labels for vpassport_2858.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2858.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2858_debug.jpg
# Saved labels for vpassport_2493.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2493.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2493_debug.jpg
# Saved labels for vpassport_1233.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1233.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1233_debug.jpg
# Saved labels for vpassport_628.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_628.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_628_debug.jpg
# Saved labels for vpassport_2536.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2536.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2536_debug.jpg
# Saved labels for vpassport_955.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_955.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_955_debug.jpg
# Saved labels for vpassport_2316.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2316.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2316_debug.jpg
# Saved labels for vpassport_266.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_266.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_266_debug.jpg
# Saved labels for vpassport_2242.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2242.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2242_debug.jpg
# Saved labels for vpassport_1620.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1620.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1620_debug.jpg
# Saved labels for vpassport_212.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_212.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_212_debug.jpg
# Saved labels for vpassport_1454.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1454.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1454_debug.jpg
# Saved labels for vpassport_1429.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1429.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1429_debug.jpg
# Saved labels for vpassport_1056.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1056.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1056_debug.jpg
# Saved labels for vpassport_567.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_567.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_567_debug.jpg
# Saved labels for vpassport_1632.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1632.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1632_debug.jpg
# Saved labels for vpassport_1759.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1759.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1759_debug.jpg
# Saved labels for vpassport_2838.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2838.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2838_debug.jpg
# Saved labels for vpassport_1204.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1204.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1204_debug.jpg
# Saved labels for vpassport_803.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_803.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_803_debug.jpg
# Saved labels for vpassport_2344.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2344.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2344_debug.jpg
# Saved labels for vpassport_1488.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1488.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1488_debug.jpg
# Saved labels for vpassport_443.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_443.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_443_debug.jpg
# Saved labels for vpassport_876.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_876.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_876_debug.jpg
# Saved labels for vpassport_75.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_75.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_75_debug.jpg
# Saved labels for vpassport_573.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_573.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_573_debug.jpg
# Saved labels for vpassport_1549.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1549.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1549_debug.jpg
# Saved labels for vpassport_1326.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1326.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1326_debug.jpg
# Saved labels for vpassport_286.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_286.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_286_debug.jpg
# Saved labels for vpassport_509.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_509.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_509_debug.jpg
# Saved labels for vpassport_149.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_149.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_149_debug.jpg
# Saved labels for vpassport_1173.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1173.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1173_debug.jpg
# Saved labels for vpassport_208.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_208.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_208_debug.jpg
# Saved labels for vpassport_2158.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2158.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2158_debug.jpg
# Saved labels for vpassport_231.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_231.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_231_debug.jpg
# Saved labels for vpassport_1908.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1908.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1908_debug.jpg
# Saved labels for vpassport_877.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_877.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_877_debug.jpg
# Saved labels for vpassport_2518.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2518.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2518_debug.jpg
# Saved labels for vpassport_79.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_79.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_79_debug.jpg
# Saved labels for vpassport_80.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_80.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_80_debug.jpg
# Saved labels for vpassport_309.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_309.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_309_debug.jpg
# Saved labels for vpassport_308.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_308.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_308_debug.jpg
# Saved labels for vpassport_530.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_530.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_530_debug.jpg
# Saved labels for vpassport_1210.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1210.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1210_debug.jpg
# Saved labels for vpassport_1793.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1793.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1793_debug.jpg
# Saved labels for vpassport_2246.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2246.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2246_debug.jpg
# Saved labels for vpassport_2676.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2676.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2676_debug.jpg
# Saved labels for vpassport_529.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_529.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_529_debug.jpg
# Saved labels for vpassport_1794.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1794.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1794_debug.jpg
# Saved labels for vpassport_921.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_921.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_921_debug.jpg
# Saved labels for vpassport_800.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_800.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_800_debug.jpg
# Saved labels for vpassport_1545.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1545.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1545_debug.jpg
# Saved labels for vpassport_2817.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2817.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2817_debug.jpg
# Saved labels for vpassport_216.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_216.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_216_debug.jpg
# Saved labels for vpassport_2172.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2172.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2172_debug.jpg
# Saved labels for vpassport_1755.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1755.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1755_debug.jpg
# Saved labels for vpassport_1522.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1522.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1522_debug.jpg
# Saved labels for vpassport_1340.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1340.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1340_debug.jpg
# Saved labels for vpassport_1630.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1630.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1630_debug.jpg
# Saved labels for vpassport_2712.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2712.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2712_debug.jpg
# Saved labels for vpassport_2464.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2464.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2464_debug.jpg
# Saved labels for vpassport_1681.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1681.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1681_debug.jpg
# Saved labels for vpassport_697.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_697.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_697_debug.jpg
# Saved labels for vpassport_666.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_666.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_666_debug.jpg
# Saved labels for vpassport_864.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_864.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_864_debug.jpg
# Saved labels for vpassport_1448.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1448.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1448_debug.jpg
# Saved labels for vpassport_457.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_457.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_457_debug.jpg
# Saved labels for vpassport_1561.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1561.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1561_debug.jpg
# Saved labels for vpassport_634.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_634.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_634_debug.jpg
# Saved labels for vpassport_1311.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1311.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1311_debug.jpg
# Saved labels for vpassport_1337.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1337.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1337_debug.jpg
# Saved labels for vpassport_2727.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2727.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2727_debug.jpg
# Saved labels for vpassport_1177.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1177.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1177_debug.jpg
# Saved labels for vpassport_2153.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2153.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2153_debug.jpg
# Saved labels for vpassport_1677.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1677.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1677_debug.jpg
# Saved labels for vpassport_2885.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2885.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2885_debug.jpg
# Saved labels for vpassport_1847.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1847.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1847_debug.jpg
# Saved labels for vpassport_729.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_729.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_729_debug.jpg
# Saved labels for vpassport_638.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_638.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_638_debug.jpg
# Saved labels for vpassport_2051.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2051.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2051_debug.jpg
# Saved labels for vpassport_1264.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1264.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1264_debug.jpg
# Saved labels for vpassport_2267.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2267.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2267_debug.jpg
# Saved labels for vpassport_1220.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1220.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1220_debug.jpg
# Saved labels for vpassport_1535.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1535.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1535_debug.jpg
# Saved labels for vpassport_395.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_395.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_395_debug.jpg
# Saved labels for vpassport_2067.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2067.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2067_debug.jpg
# Saved labels for vpassport_1353.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1353.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1353_debug.jpg
# Saved labels for vpassport_2489.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2489.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2489_debug.jpg
# Saved labels for vpassport_539.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_539.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_539_debug.jpg
# Saved labels for vpassport_1720.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1720.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1720_debug.jpg
# Saved labels for vpassport_684.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_684.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_684_debug.jpg
# Saved labels for vpassport_2529.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2529.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2529_debug.jpg
# Saved labels for vpassport_1386.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1386.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1386_debug.jpg
# Saved labels for vpassport_49.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_49.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_49_debug.jpg
# Saved labels for vpassport_2620.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2620.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2620_debug.jpg
# Saved labels for vpassport_74.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_74.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_74_debug.jpg
# Saved labels for vpassport_1117.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1117.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1117_debug.jpg
# Saved labels for vpassport_2330.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2330.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2330_debug.jpg
# Saved labels for vpassport_2849.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2849.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2849_debug.jpg
# Saved labels for vpassport_1888.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1888.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1888_debug.jpg
# Saved labels for vpassport_868.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_868.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_868_debug.jpg
# Saved labels for vpassport_242.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_242.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_242_debug.jpg
# Saved labels for vpassport_751.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_751.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_751_debug.jpg
# Saved labels for vpassport_1195.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1195.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1195_debug.jpg
# Saved labels for vpassport_226.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_226.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_226_debug.jpg
# Saved labels for vpassport_645.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_645.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_645_debug.jpg
# Saved labels for vpassport_275.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_275.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_275_debug.jpg
# Saved labels for vpassport_891.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_891.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_891_debug.jpg
# Saved labels for vpassport_376.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_376.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_376_debug.jpg
# Saved labels for vpassport_2303.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2303.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2303_debug.jpg
# Saved labels for vpassport_1202.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1202.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1202_debug.jpg
# Saved labels for vpassport_2503.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2503.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2503_debug.jpg
# Saved labels for vpassport_120.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_120.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_120_debug.jpg
# Saved labels for vpassport_2886.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2886.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2886_debug.jpg
# Saved labels for vpassport_328.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_328.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_328_debug.jpg
# Saved labels for vpassport_455.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_455.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_455_debug.jpg
# Saved labels for vpassport_796.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_796.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_796_debug.jpg
# Saved labels for vpassport_1455.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1455.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1455_debug.jpg
# Saved labels for vpassport_134.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_134.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_134_debug.jpg
# Saved labels for vpassport_2980.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2980.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2980_debug.jpg
# Saved labels for vpassport_306.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_306.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_306_debug.jpg
# Saved labels for vpassport_2439.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2439.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2439_debug.jpg
# Saved labels for vpassport_1400.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1400.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1400_debug.jpg
# Saved labels for vpassport_1603.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1603.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1603_debug.jpg
# Saved labels for vpassport_374.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_374.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_374_debug.jpg
# Saved labels for vpassport_58.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_58.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_58_debug.jpg
# Saved labels for vpassport_1815.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1815.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1815_debug.jpg
# Saved labels for vpassport_1517.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1517.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1517_debug.jpg
# Saved labels for vpassport_566.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_566.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_566_debug.jpg
# Saved labels for vpassport_1368.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1368.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1368_debug.jpg
# Saved labels for vpassport_322.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_322.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_322_debug.jpg
# Saved labels for vpassport_1878.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1878.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1878_debug.jpg
# Saved labels for vpassport_333.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_333.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_333_debug.jpg
# Saved labels for vpassport_2005.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2005.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2005_debug.jpg
# Saved labels for vpassport_2120.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2120.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2120_debug.jpg
# Saved labels for vpassport_460.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_460.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_460_debug.jpg
# Saved labels for vpassport_1255.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1255.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1255_debug.jpg
# Saved labels for vpassport_1870.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1870.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1870_debug.jpg
# Saved labels for vpassport_2215.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2215.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2215_debug.jpg
# Saved labels for vpassport_982.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_982.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_982_debug.jpg
# Saved labels for vpassport_2668.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2668.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2668_debug.jpg
# Saved labels for vpassport_753.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_753.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_753_debug.jpg
# Saved labels for vpassport_99.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_99.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_99_debug.jpg
# Saved labels for vpassport_1934.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1934.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1934_debug.jpg
# Saved labels for vpassport_822.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_822.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_822_debug.jpg
# Saved labels for vpassport_2099.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2099.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2099_debug.jpg
# Saved labels for vpassport_1191.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1191.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1191_debug.jpg
# Saved labels for vpassport_2930.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2930.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2930_debug.jpg
# Saved labels for vpassport_1711.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1711.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1711_debug.jpg
# Saved labels for vpassport_999.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_999.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_999_debug.jpg
# Saved labels for vpassport_1922.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1922.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1922_debug.jpg
# Saved labels for vpassport_1941.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1941.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1941_debug.jpg
# Saved labels for vpassport_289.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_289.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_289_debug.jpg
# Saved labels for vpassport_682.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_682.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_682_debug.jpg
# Saved labels for vpassport_1372.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1372.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1372_debug.jpg
# Saved labels for vpassport_2185.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2185.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2185_debug.jpg
# Saved labels for vpassport_378.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_378.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_378_debug.jpg
# Saved labels for vpassport_1622.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1622.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1622_debug.jpg
# Saved labels for vpassport_1447.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1447.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1447_debug.jpg
# Saved labels for vpassport_97.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_97.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_97_debug.jpg
# Saved labels for vpassport_1649.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1649.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1649_debug.jpg
# Saved labels for vpassport_1515.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1515.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1515_debug.jpg
# Saved labels for vpassport_340.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_340.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_340_debug.jpg
# Saved labels for vpassport_248.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_248.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_248_debug.jpg
# Saved labels for vpassport_1504.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1504.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1504_debug.jpg
# Saved labels for vpassport_2903.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2903.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2903_debug.jpg
# Saved labels for vpassport_430.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_430.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_430_debug.jpg
# Saved labels for vpassport_2262.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2262.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2262_debug.jpg
# Saved labels for vpassport_1147.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1147.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1147_debug.jpg
# Saved labels for vpassport_185.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_185.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_185_debug.jpg
# Saved labels for vpassport_15.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_15.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_15_debug.jpg
# Saved labels for vpassport_2423.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2423.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2423_debug.jpg
# Saved labels for vpassport_1323.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1323.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1323_debug.jpg
# Saved labels for vpassport_698.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_698.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_698_debug.jpg
# Saved labels for vpassport_1539.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1539.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1539_debug.jpg
# Saved labels for vpassport_531.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_531.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_531_debug.jpg
# Saved labels for vpassport_450.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_450.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_450_debug.jpg
# Saved labels for vpassport_1232.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1232.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1232_debug.jpg
# Saved labels for vpassport_1593.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1593.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1593_debug.jpg
# Saved labels for vpassport_1917.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1917.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1917_debug.jpg
# Saved labels for vpassport_2034.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2034.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2034_debug.jpg
# Saved labels for vpassport_1461.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1461.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1461_debug.jpg
# Saved labels for vpassport_2626.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2626.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2626_debug.jpg
# Saved labels for vpassport_2780.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2780.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2780_debug.jpg
# Saved labels for vpassport_118.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_118.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_118_debug.jpg
# Saved labels for vpassport_2585.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2585.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2585_debug.jpg
# Saved labels for vpassport_2234.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2234.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2234_debug.jpg
# Saved labels for vpassport_1283.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1283.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1283_debug.jpg
# Saved labels for vpassport_326.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_326.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_326_debug.jpg
# Saved labels for vpassport_263.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_263.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_263_debug.jpg
# Saved labels for vpassport_1638.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1638.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1638_debug.jpg
# ...
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_261_debug.jpg
# Saved labels for vpassport_2161.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2161.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2161_debug.jpg
# Saved labels for vpassport_2836.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2836.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2836_debug.jpg
# Saved labels for vpassport_94.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_94.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_94_debug.jpg
# Saved labels for vpassport_1927.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1927.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1927_debug.jpg
# Saved labels for vpassport_1295.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1295.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1295_debug.jpg
# Saved labels for vpassport_2752.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2752.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2752_debug.jpg
# Saved labels for vpassport_845.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_845.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_845_debug.jpg
# Saved labels for vpassport_938.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_938.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_938_debug.jpg
# Saved labels for vpassport_1088.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1088.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1088_debug.jpg
# Saved labels for vpassport_1355.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1355.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1355_debug.jpg
# Saved labels for vpassport_1315.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1315.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1315_debug.jpg
# Saved labels for vpassport_157.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_157.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_157_debug.jpg
# Saved labels for vpassport_1074.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1074.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1074_debug.jpg
# Saved labels for vpassport_2231.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2231.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2231_debug.jpg
# Saved labels for vpassport_240.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_240.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_240_debug.jpg
# Saved labels for vpassport_2322.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2322.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2322_debug.jpg
# Saved labels for vpassport_2598.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2598.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2598_debug.jpg
# Saved labels for vpassport_951.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_951.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_951_debug.jpg
# Saved labels for vpassport_2588.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2588.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2588_debug.jpg
# Saved labels for vpassport_2722.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2722.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2722_debug.jpg
# Saved labels for vpassport_815.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_815.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_815_debug.jpg
# Saved labels for vpassport_319.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_319.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_319_debug.jpg
# Saved labels for vpassport_2652.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2652.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2652_debug.jpg
# Saved labels for vpassport_2392.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2392.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2392_debug.jpg
# Saved labels for vpassport_1025.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1025.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1025_debug.jpg
# Saved labels for vpassport_2424.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2424.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2424_debug.jpg
# Saved labels for vpassport_102.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_102.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_102_debug.jpg
# Saved labels for vpassport_34.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_34.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_34_debug.jpg
# Saved labels for vpassport_1701.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1701.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1701_debug.jpg
# Saved labels for vpassport_191.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_191.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_191_debug.jpg
# Saved labels for vpassport_2534.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2534.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2534_debug.jpg
# Saved labels for vpassport_271.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_271.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_271_debug.jpg
# Saved labels for vpassport_435.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_435.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_435_debug.jpg
# Saved labels for vpassport_2065.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2065.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2065_debug.jpg
# Saved labels for vpassport_1807.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1807.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1807_debug.jpg
# Saved labels for vpassport_1260.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1260.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1260_debug.jpg
# Saved labels for vpassport_2335.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2335.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2335_debug.jpg
# Saved labels for vpassport_1227.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1227.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1227_debug.jpg
# Saved labels for vpassport_2857.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2857.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2857_debug.jpg
# Saved labels for vpassport_1119.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1119.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1119_debug.jpg
# Saved labels for vpassport_1780.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1780.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1780_debug.jpg
# Saved labels for vpassport_1628.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1628.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1628_debug.jpg
# Saved labels for vpassport_2157.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2157.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2157_debug.jpg
# Saved labels for vpassport_2228.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2228.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2228_debug.jpg
# Saved labels for vpassport_1976.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1976.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1976_debug.jpg
# Saved labels for vpassport_2890.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2890.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2890_debug.jpg
# Saved labels for vpassport_2472.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2472.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2472_debug.jpg
# Saved labels for vpassport_70.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_70.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_70_debug.jpg
# Saved labels for vpassport_2669.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2669.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2669_debug.jpg
# Saved labels for vpassport_2909.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2909.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2909_debug.jpg
# Saved labels for vpassport_2154.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2154.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2154_debug.jpg
# Saved labels for vpassport_1761.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1761.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1761_debug.jpg
# Saved labels for vpassport_2054.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2054.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2054_debug.jpg
# Saved labels for vpassport_2627.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2627.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2627_debug.jpg
# Saved labels for vpassport_2261.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2261.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2261_debug.jpg
# Saved labels for vpassport_2659.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2659.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2659_debug.jpg
# Saved labels for vpassport_2580.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2580.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2580_debug.jpg
# Saved labels for vpassport_1699.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1699.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1699_debug.jpg
# Saved labels for vpassport_1689.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1689.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1689_debug.jpg
# Saved labels for vpassport_1121.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1121.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1121_debug.jpg
# Saved labels for vpassport_113.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_113.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_113_debug.jpg
# Saved labels for vpassport_2367.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2367.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2367_debug.jpg
# Saved labels for vpassport_2772.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2772.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2772_debug.jpg
# Saved labels for vpassport_298.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_298.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_298_debug.jpg
# Saved labels for vpassport_1810.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1810.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1810_debug.jpg
# Saved labels for vpassport_1007.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1007.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_1007_debug.jpg
# Saved labels for vpassport_2531.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2531.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_2531_debug.jpg
# Saved labels for vpassport_404.jpg to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_404.txt
# Saved debug image to /content/drive/My Drive/OCRTraining/PassportDataset/train/labels/vpassport_404_debug.jpg
# Label generation complete!

# %% [markdown]
# # Using Fast R-CNN (Pytorch) to Train Best Model
# For Synthetic Dataset

# %% [markdown]
# **Faster R-CNN** (via PyTorch or TensorFlow Object Detection API):
#
# Accepts bounding box coordinates in the format `x_min, y_min, x_max, y_max`.
# Can handle custom datasets and outputs confidence scores for each predicted bounding box and class.
#
# **Dataset Class**:\
# Reads images and corresponding label files.
# Prepares the data in the required format for PyTorch.
#
# **Model:**\
# Uses Faster R-CNN with a ResNet-50 backbone.
# Adjusts the final layer for the number of classes.
#
# **Accuracy Computation:**\
# Add evaluation logic using IoU (Intersection over Union) or another metric.
#
# **Result:**\
# The best model with accuracy above 70% will be saved in /content/drive/My Drive/OCRTraining/PassportDataset/train/model/.

# %%
import os
import torch
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.transforms import functional as F
from torch.utils.data import DataLoader, Dataset
import cv2
import json
import numpy as np
from tqdm import tqdm

# Dataset Class
class PassportDataset(Dataset):
    def __init__(self, image_dir, label_dir, transforms=None):
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.transforms = transforms
        self.image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        image_file = self.image_files[idx]
        label_file = os.path.splitext(image_file)[0] + ".txt"

        # Load image
        image_path = os.path.join(self.image_dir, image_file)
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Load labels
        label_path = os.path.join(self.label_dir, label_file)
        with open(label_path, 'r') as f:
            lines = f.readlines()

        boxes = []
        labels = []
        for line in lines:
            parts = line.strip().split()
            if len(parts) != 5:
                continue
            class_id, x_min, y_min, x_max, y_max = map(int, parts)
            boxes.append([x_min, y_min, x_max, y_max])
            labels.append(class_id)

        # Convert to tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        target = {"boxes": boxes, "labels": labels}

        if self.transforms:
            image = self.transforms(image)

        return F.to_tensor(image), target

# Define Model
def get_model(num_classes):
    model = fasterrcnn_resnet50_fpn(pretrained=True)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    return model

# Training Loop
def train_one_epoch(model, optimizer, data_loader, device):
    model.train()
    epoch_loss = 0
    for images, targets in tqdm(data_loader):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        epoch_loss += losses.item()

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

    return epoch_loss / len(data_loader)

# Compute IoU
def compute_iou(box1, box2):
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])

    inter_area = max(0, x2 - x1) * max(0, y2 - y1)
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])

    iou = inter_area / (box1_area + box2_area - inter_area + 1e-6)
    return iou

# Evaluate Model
def evaluate_model(model, data_loader, device, iou_threshold=0.5):
    model.eval()
    total_predictions = 0
    correct_predictions = 0

    with torch.no_grad():
        for images, targets in tqdm(data_loader):
            images = list(image.to(device) for image in images)
            outputs = model(images)

            for i, output in enumerate(outputs):
                pred_boxes = output['boxes'].cpu().numpy()
                pred_labels = output['labels'].cpu().numpy()
                gt_boxes = targets[i]['boxes'].cpu().numpy()
                gt_labels = targets[i]['labels'].cpu().numpy()

                for gt_box, gt_label in zip(gt_boxes, gt_labels):
                    total_predictions += 1
                    for pred_box, pred_label in zip(pred_boxes, pred_labels):
                        if pred_label == gt_label:
                            iou = compute_iou(gt_box, pred_box)
                            if iou >= iou_threshold:
                                correct_predictions += 1
                                break

    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    return accuracy

# Paths
train_image_dir = "/content/drive/My Drive/OCRTraining/PassportDataset/train/images/"
train_label_dir = "/content/drive/My Drive/OCRTraining/PassportDataset/train/labels/"
test_image_dir = "/content/drive/My Drive/OCRTraining/PassportDataset/test/images/"
test_label_dir = "/content/drive/My Drive/OCRTraining/PassportDataset/test/labels/"
model_save_dir = "/content/drive/My Drive/OCRTraining/PassportDataset/train/model/"

# Hyperparameters
num_classes = 10  # Number of classes (including background)
num_epochs = 20
batch_size = 4
learning_rate = 0.005

# Prepare Dataset and Dataloader
train_dataset = PassportDataset(train_image_dir, train_label_dir)
test_dataset = PassportDataset(test_image_dir, test_label_dir)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))

# Device
# device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device = torch.device("cpu")

# Initialize Model
model = get_model(num_classes).to(device)

# Optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0005)

# Train and Save Best Model
best_accuracy = 0
lowest_loss = float('inf')  # Track the lowest loss

for epoch in range(num_epochs):
    train_loss = train_one_epoch(model, optimizer, train_loader, device)
    print(f"Epoch {epoch + 1}, Loss: {train_loss:.4f}")

    # Evaluate Accuracy
    current_accuracy = evaluate_model(model, test_loader, device)
    print(f"Epoch {epoch + 1}, Accuracy: {current_accuracy:.4f}")

    # Save model only if conditions are met
    if train_loss <= 0.07:  # Skip saving if loss > 0.07
        # Save the best model so the one with the highest accuracy (from history)
        # Or scenarioing 2 equals accuracy then it will be determined by the loss metric
        if current_accuracy > best_accuracy or (current_accuracy == best_accuracy and train_loss < lowest_loss):
            best_accuracy = current_accuracy
            lowest_loss = train_loss
            model_path = os.path.join(model_save_dir, f"best_model_{best_accuracy:.2f}_{train_loss:.4f}.pth")
            torch.save(model.state_dict(), model_path)
            print(f"Saved Best Model with Accuracy: {best_accuracy:.2f}, Loss: {lowest_loss:.4f}")
# Done
print("Training Complete!")
# Out:
# 100%|██████████| 417/417 [3:24:40<00:00, 29.45s/it]
# Epoch 1, Loss: 0.4530
# 100%|██████████| 150/150 [41:47<00:00, 16.72s/it]
# Epoch 1, Accuracy: 0.8875
# 100%|██████████| 417/417 [2:07:57<00:00, 18.41s/it]
# Epoch 2, Loss: 0.1351
# 100%|██████████| 150/150 [17:04<00:00,  6.83s/it]
# Epoch 2, Accuracy: 0.8875
# 100%|██████████| 417/417 [2:08:15<00:00, 18.45s/it]
# Epoch 3, Loss: 0.0874
# 100%|██████████| 150/150 [18:15<00:00,  7.30s/it]
# Epoch 3, Accuracy: 0.8873
# 100%|██████████| 417/417 [2:06:11<00:00, 18.16s/it]
# Epoch 4, Loss: 0.0678
# 100%|██████████| 150/150 [16:42<00:00,  6.68s/it]
# Epoch 4, Accuracy: 0.8875
# Saved Best Model with Accuracy: 0.89, Loss: 0.0678
#  26%|██▌       | 107/417 [32:15<1:32:44, 17.95s/it]

# %% [markdown]
# # Manual Testing on Best Model Accuracy 1
# This script having error when rotating the rectangle\
# For Synthetic Dataset

# %% [markdown]
# Import Dependencies TourchVision and FastRCNN

# %%
# OpenCV TorchVision
# !pip install torch torchvision opencv-python
# Install PyTorch that matches the Colab environment
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu11
# Install Detectron2 engine from GitHub
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Looking in indexes: https://download.pytorch.org/whl/cu11
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-2jag7g2o
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-2jag7g2o
#   Resolved https://github.com/facebookresearch/detectron2.git to commit b1c43ffbc995426a9a6b5c667730091a384e0fa4
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (11.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.8.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.8)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.5.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.1.0)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.67.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.17.1)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl.metadata (370 bytes)
# Collecting omegaconf<2.4,>=2.1 (from detectron2==0.6)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting black (from detectron2==0.6)
#   Downloading black-24.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.2)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-3.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.7)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.3.6)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.12.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (3.0.2)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 11.8 MB/s eta 0:00:00
# Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.2 MB/s eta 0:00:00
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading black-24.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 36.0 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading portalocker-3.0.0-py3-none-any.whl (19 kB)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=5974688 sha256=12691ad41d13f0ea6b2c0100e86d254a31796c751f4dc9f482753dab57bdafc7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v0cb38c4/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61396 sha256=d58fa4e4ef1708d292d36d3614bd5df1fb0f38e782011039fc4557507e44d4ed
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=8542ba009b86cee9f7b16c55183f4596f0a008cc716b2762df066ed9fe408775
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-24.10.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.12.1 portalocker-3.0.0 yacs-0.1.8

# %%
# Install detection dependencies
# !pip install detectron2
# Out:
# Requirement already satisfied: detectron2 in /usr/local/lib/python3.10/dist-packages (0.6)
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2) (11.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2) (3.8.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2) (2.0.8)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2) (2.5.0)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.10/dist-packages (from detectron2) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2) (3.1.0)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2) (4.67.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2) (2.17.1)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from detectron2) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from detectron2) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.10/dist-packages (from detectron2) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from detectron2) (24.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2) (24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2) (6.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1->detectron2) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2) (3.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->detectron2) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2) (4.3.6)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->detectron2) (4.12.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2) (3.0.2)

# %%
# Clone to Detectron2 GitHub for configs file usage
# !git clone https://github.com/facebookresearch/detectron2.git
# Out:
# fatal: destination path 'detectron2' already exists and is not an empty directory.
# detectron2  drive  sample_data

# %%
# Make sure config yaml file exist
# !ls detectron2/configs/COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml
# Out:
# detectron2/configs/COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml

# %%
import os
import cv2
import torch
import numpy as np
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.data import MetadataCatalog
from detectron2.utils.visualizer import Visualizer
from detectron2.structures import RotatedBoxes

# Class Mapping
classes = {
    0: "fullname",
    1: "nationality",
    2: "dob",
    3: "sex",
    4: "pob",
    5: "cmnd",
    6: "passportid",
    7: "nameid",
    8: "passportid2"
}

# Configure Detectron2
def configure_detectron2(model_path, num_classes):
    """
    Configure Detectron2 with proper settings.
    """
    cfg = get_cfg()
    config_path = "detectron2/configs/COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"
    assert os.path.exists(config_path), f"Configuration file not found at {config_path}"
    cfg.merge_from_file(config_path)
    cfg.MODEL.ROI_HEADS.NUM_CLASSES = num_classes  # Ensure it matches training configuration
    cfg.MODEL.WEIGHTS = model_path
    cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.3
    cfg.MODEL.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    return cfg


def draw_axis_aligned_box(image, box, color, class_name, score):
    """
    Draw an axis-aligned bounding box with the given parameters.
    """
    x_min, y_min, x_max, y_max = map(int, box)
    cv2.rectangle(image, (x_min, y_min), (x_max, y_max), color, 2)
    cv2.putText(
        image, f"{class_name} ({score:.2f})", (x_min, y_min - 10),
        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1, cv2.LINE_AA
    )


def visualize_predictions(image_path, predictor, output_path):
    """
    Visualize predictions with axis-aligned bounding boxes.
    """
    image = cv2.imread(image_path)
    outputs = predictor(image)

    # Predictions
    predictions = outputs["instances"].to("cpu")
    boxes = predictions.pred_boxes.tensor.numpy()  # Axis-aligned boxes
    scores = predictions.scores.numpy()
    pred_classes = predictions.pred_classes.numpy()

    for box, score, class_id in zip(boxes, scores, pred_classes):
        class_name = classes.get(class_id, "unknown")
        draw_axis_aligned_box(image, box, (0, 255, 0), class_name, score)

    # Debug outputs
    print(f"Predicted Boxes: {boxes}")
    print(f"Predicted Scores: {scores}")
    print(f"Predicted Classes: {pred_classes}")

    # Save output
    cv2.imwrite(output_path, image)
    print(f"Predictions saved to {output_path}")


# Test ID and Model
test_id = 2893  # Example
num_classes = len(classes)

# Paths
model_path = f"/content/drive/My Drive/OCRTraining/PassportDataset/train/model/best_model_{ba}_{bl}.pth"
image_path = f"/content/drive/My Drive/OCRTraining/PassportDataset/test/images/vpassport_{test_id}.jpg"
output_path = f"/content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_passport/predicted_vpassport_{test_id}.jpg"

# Load Model and Predictor
cfg = configure_detectron2(model_path, num_classes)
predictor = DefaultPredictor(cfg)

# Run Predictions
visualize_predictions(image_path, predictor, output_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/fvcore/common/checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (40, 1024) in the checkpoint but (36, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (40,) in the checkpoint but (36,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# backbone.bottom_up.res2.0.conv1.norm.{bias, weight}
# backbone.bottom_up.res2.0.conv1.weight
# backbone.bottom_up.res2.0.conv2.norm.{bias, weight}
# backbone.bottom_up.res2.0.conv2.weight
# backbone.bottom_up.res2.0.conv3.norm.{bias, weight}
# backbone.bottom_up.res2.0.conv3.weight
# backbone.bottom_up.res2.0.shortcut.norm.{bias, weight}
# backbone.bottom_up.res2.0.shortcut.weight
# backbone.bottom_up.res2.1.conv1.norm.{bias, weight}
# backbone.bottom_up.res2.1.conv1.weight
# backbone.bottom_up.res2.1.conv2.norm.{bias, weight}
# backbone.bottom_up.res2.1.conv2.weight
# backbone.bottom_up.res2.1.conv3.norm.{bias, weight}
# backbone.bottom_up.res2.1.conv3.weight
# backbone.bottom_up.res2.2.conv1.norm.{bias, weight}
# backbone.bottom_up.res2.2.conv1.weight
# backbone.bottom_up.res2.2.conv2.norm.{bias, weight}
# backbone.bottom_up.res2.2.conv2.weight
# backbone.bottom_up.res2.2.conv3.norm.{bias, weight}
# backbone.bottom_up.res2.2.conv3.weight
# backbone.bottom_up.res3.0.conv1.norm.{bias, weight}
# backbone.bottom_up.res3.0.conv1.weight
# backbone.bottom_up.res3.0.conv2.norm.{bias, weight}
# backbone.bottom_up.res3.0.conv2.weight
# backbone.bottom_up.res3.0.conv3.norm.{bias, weight}
# backbone.bottom_up.res3.0.conv3.weight
# backbone.bottom_up.res3.0.shortcut.norm.{bias, weight}
# backbone.bottom_up.res3.0.shortcut.weight
# backbone.bottom_up.res3.1.conv1.norm.{bias, weight}
# backbone.bottom_up.res3.1.conv1.weight
# backbone.bottom_up.res3.1.conv2.norm.{bias, weight}
# backbone.bottom_up.res3.1.conv2.weight
# backbone.bottom_up.res3.1.conv3.norm.{bias, weight}
# backbone.bottom_up.res3.1.conv3.weight
# backbone.bottom_up.res3.2.conv1.norm.{bias, weight}
# backbone.bottom_up.res3.2.conv1.weight
# backbone.bottom_up.res3.2.conv2.norm.{bias, weight}
# backbone.bottom_up.res3.2.conv2.weight
# backbone.bottom_up.res3.2.conv3.norm.{bias, weight}
# backbone.bottom_up.res3.2.conv3.weight
# backbone.bottom_up.res3.3.conv1.norm.{bias, weight}
# backbone.bottom_up.res3.3.conv1.weight
# backbone.bottom_up.res3.3.conv2.norm.{bias, weight}
# backbone.bottom_up.res3.3.conv2.weight
# backbone.bottom_up.res3.3.conv3.norm.{bias, weight}
# backbone.bottom_up.res3.3.conv3.weight
# backbone.bottom_up.res4.0.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.0.conv1.weight
# backbone.bottom_up.res4.0.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.0.conv2.weight
# backbone.bottom_up.res4.0.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.0.conv3.weight
# backbone.bottom_up.res4.0.shortcut.norm.{bias, weight}
# backbone.bottom_up.res4.0.shortcut.weight
# backbone.bottom_up.res4.1.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.1.conv1.weight
# backbone.bottom_up.res4.1.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.1.conv2.weight
# backbone.bottom_up.res4.1.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.1.conv3.weight
# backbone.bottom_up.res4.2.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.2.conv1.weight
# backbone.bottom_up.res4.2.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.2.conv2.weight
# backbone.bottom_up.res4.2.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.2.conv3.weight
# backbone.bottom_up.res4.3.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.3.conv1.weight
# backbone.bottom_up.res4.3.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.3.conv2.weight
# backbone.bottom_up.res4.3.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.3.conv3.weight
# backbone.bottom_up.res4.4.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.4.conv1.weight
# backbone.bottom_up.res4.4.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.4.conv2.weight
# backbone.bottom_up.res4.4.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.4.conv3.weight
# backbone.bottom_up.res4.5.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.5.conv1.weight
# backbone.bottom_up.res4.5.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.5.conv2.weight
# backbone.bottom_up.res4.5.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.5.conv3.weight
# backbone.bottom_up.res5.0.conv1.norm.{bias, weight}
# backbone.bottom_up.res5.0.conv1.weight
# backbone.bottom_up.res5.0.conv2.norm.{bias, weight}
# backbone.bottom_up.res5.0.conv2.weight
# backbone.bottom_up.res5.0.conv3.norm.{bias, weight}
# backbone.bottom_up.res5.0.conv3.weight
# backbone.bottom_up.res5.0.shortcut.norm.{bias, weight}
# backbone.bottom_up.res5.0.shortcut.weight
# backbone.bottom_up.res5.1.conv1.norm.{bias, weight}
# backbone.bottom_up.res5.1.conv1.weight
# backbone.bottom_up.res5.1.conv2.norm.{bias, weight}
# backbone.bottom_up.res5.1.conv2.weight
# backbone.bottom_up.res5.1.conv3.norm.{bias, weight}
# backbone.bottom_up.res5.1.conv3.weight
# backbone.bottom_up.res5.2.conv1.norm.{bias, weight}
# backbone.bottom_up.res5.2.conv1.weight
# backbone.bottom_up.res5.2.conv2.norm.{bias, weight}
# backbone.bottom_up.res5.2.conv2.weight
# backbone.bottom_up.res5.2.conv3.norm.{bias, weight}
# backbone.bottom_up.res5.2.conv3.weight
# backbone.bottom_up.stem.conv1.norm.{bias, weight}
# backbone.bottom_up.stem.conv1.weight
# backbone.fpn_lateral2.{bias, weight}
# backbone.fpn_lateral3.{bias, weight}
# backbone.fpn_lateral4.{bias, weight}
# backbone.fpn_lateral5.{bias, weight}
# backbone.fpn_output2.{bias, weight}
# backbone.fpn_output3.{bias, weight}
# backbone.fpn_output4.{bias, weight}
# backbone.fpn_output5.{bias, weight}
# proposal_generator.rpn_head.anchor_deltas.{bias, weight}
# proposal_generator.rpn_head.conv.{bias, weight}
# proposal_generator.rpn_head.objectness_logits.{bias, weight}
# roi_heads.box_head.fc1.{bias, weight}
# roi_heads.box_head.fc2.{bias, weight}
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# WARNING:fvcore.common.checkpoint:The checkpoint state_dict contains keys that are not used by the model:
#   rpn.head.conv.0.0.{bias, weight}
#   rpn.head.cls_logits.{bias, weight}
#   rpn.head.bbox_pred.{bias, weight}
#   backbone.body.conv1.weight
#   backbone.body.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer1.0.conv1.weight
#   backbone.body.layer1.0.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer1.0.conv2.weight
#   backbone.body.layer1.0.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer1.0.conv3.weight
#   backbone.body.layer1.0.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer1.0.downsample.0.weight
#   backbone.body.layer1.0.downsample.1.{bias, running_mean, running_var, weight}
#   backbone.body.layer1.1.conv1.weight
#   backbone.body.layer1.1.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer1.1.conv2.weight
#   backbone.body.layer1.1.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer1.1.conv3.weight
#   backbone.body.layer1.1.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer1.2.conv1.weight
#   backbone.body.layer1.2.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer1.2.conv2.weight
#   backbone.body.layer1.2.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer1.2.conv3.weight
#   backbone.body.layer1.2.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.0.conv1.weight
#   backbone.body.layer2.0.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.0.conv2.weight
#   backbone.body.layer2.0.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.0.conv3.weight
#   backbone.body.layer2.0.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.0.downsample.0.weight
#   backbone.body.layer2.0.downsample.1.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.1.conv1.weight
#   backbone.body.layer2.1.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.1.conv2.weight
#   backbone.body.layer2.1.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.1.conv3.weight
#   backbone.body.layer2.1.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.2.conv1.weight
#   backbone.body.layer2.2.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.2.conv2.weight
#   backbone.body.layer2.2.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.2.conv3.weight
#   backbone.body.layer2.2.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.3.conv1.weight
#   backbone.body.layer2.3.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.3.conv2.weight
#   backbone.body.layer2.3.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer2.3.conv3.weight
#   backbone.body.layer2.3.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.0.conv1.weight
#   backbone.body.layer3.0.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.0.conv2.weight
#   backbone.body.layer3.0.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.0.conv3.weight
#   backbone.body.layer3.0.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.0.downsample.0.weight
#   backbone.body.layer3.0.downsample.1.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.1.conv1.weight
#   backbone.body.layer3.1.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.1.conv2.weight
#   backbone.body.layer3.1.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.1.conv3.weight
#   backbone.body.layer3.1.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.2.conv1.weight
#   backbone.body.layer3.2.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.2.conv2.weight
#   backbone.body.layer3.2.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.2.conv3.weight
#   backbone.body.layer3.2.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.3.conv1.weight
#   backbone.body.layer3.3.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.3.conv2.weight
#   backbone.body.layer3.3.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.3.conv3.weight
#   backbone.body.layer3.3.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.4.conv1.weight
#   backbone.body.layer3.4.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.4.conv2.weight
#   backbone.body.layer3.4.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.4.conv3.weight
#   backbone.body.layer3.4.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.5.conv1.weight
#   backbone.body.layer3.5.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.5.conv2.weight
#   backbone.body.layer3.5.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer3.5.conv3.weight
#   backbone.body.layer3.5.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer4.0.conv1.weight
#   backbone.body.layer4.0.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer4.0.conv2.weight
#   backbone.body.layer4.0.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer4.0.conv3.weight
#   backbone.body.layer4.0.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer4.0.downsample.0.weight
#   backbone.body.layer4.0.downsample.1.{bias, running_mean, running_var, weight}
#   backbone.body.layer4.1.conv1.weight
#   backbone.body.layer4.1.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer4.1.conv2.weight
#   backbone.body.layer4.1.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer4.1.conv3.weight
#   backbone.body.layer4.1.bn3.{bias, running_mean, running_var, weight}
#   backbone.body.layer4.2.conv1.weight
#   backbone.body.layer4.2.bn1.{bias, running_mean, running_var, weight}
#   backbone.body.layer4.2.conv2.weight
#   backbone.body.layer4.2.bn2.{bias, running_mean, running_var, weight}
#   backbone.body.layer4.2.conv3.weight
#   backbone.body.layer4.2.bn3.{bias, running_mean, running_var, weight}
#   backbone.fpn.inner_blocks.0.0.{bias, weight}
#   backbone.fpn.inner_blocks.1.0.{bias, weight}
#   backbone.fpn.inner_blocks.2.0.{bias, weight}
#   backbone.fpn.inner_blocks.3.0.{bias, weight}
#   backbone.fpn.layer_blocks.0.0.{bias, weight}
#   backbone.fpn.layer_blocks.1.0.{bias, weight}
#   backbone.fpn.layer_blocks.2.0.{bias, weight}
#   backbone.fpn.layer_blocks.3.0.{bias, weight}
#   roi_heads.box_head.fc6.{bias, weight}
#   roi_heads.box_head.fc7.{bias, weight}
# Predicted Boxes: [[ 367.3512     0.       376.62714 1679.9999 ]]
# Predicted Scores: [1.]
# Predicted Classes: [0]
# Predictions saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_passport/predicted_vpassport_2893.jpg

# %% [markdown]
# # Manual Testing on Best Model Accuracy 2
# This shows only right-angled rectangle sketch\
# For Synthetic Dataset

# %%
import os
import torch
import cv2
import numpy as np
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.transforms import functional as F

# Class Mapping
classes = {
    0: "fullname",
    1: "nationality",
    2: "dob",
    3: "sex",
    4: "pob",
    5: "cmnd",
    6: "passportid",
    7: "nameid",
    8: "passportid2"
}

# Load Model
def load_model(model_path, num_classes):
    """
    Load a Faster R-CNN model with a custom number of classes and weights.
    """
    model = fasterrcnn_resnet50_fpn(pretrained=False)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    map_location = torch.device('cpu') if not torch.cuda.is_available() else None
    model.load_state_dict(torch.load(model_path, map_location=map_location))
    model.eval()
    return model

# Draw Polygon
def draw_polygon(image, box, color, class_name, score):
    """
    Draws a polygon matching the coordinates of the bounding box.
    """
    points = np.array([
        [box[0], box[1]],  # x_min, y_min
        [box[2], box[1]],  # x_max, y_min
        [box[2], box[3]],  # x_max, y_max
        [box[0], box[3]]   # x_min, y_max
    ], np.int32)
    cv2.polylines(image, [points], isClosed=True, color=color, thickness=2)
    cv2.putText(
        image, f"{class_name} ({score:.2f})", (int(box[0]), int(box[1] - 10)),
        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1, cv2.LINE_AA
    )

# Visualize Predictions
def visualize_predictions(image_path, model, device, output_path):
    """
    Visualize predictions on an image using the trained model.
    """
    image = cv2.imread(image_path)
    original_image = image.copy()
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    tensor_image = F.to_tensor(image).unsqueeze(0).to(device)

    # Make predictions
    with torch.no_grad():
        predictions = model(tensor_image)[0]

    boxes = predictions['boxes'].cpu().numpy()
    labels = predictions['labels'].cpu().numpy()
    scores = predictions['scores'].cpu().numpy()

    detected_classes = set()

    for box, label, score in zip(boxes, labels, scores):
        if score < 0.000000001:  # Confidence threshold (should lower this)
            continue
        class_name = classes[label]
        detected_classes.add(class_name)
        print(f"{class_name} {box[0]}, {box[1]}, {box[2]}, {box[3]}")
        draw_polygon(original_image, box, (0, 255, 0), class_name, score)

    # Check for missing classes
    missing_classes = set(classes.values()) - detected_classes
    if missing_classes:
        print(f"Detected field for {missing_classes} is missing, please try again")

    # Save and show results
    cv2.imwrite(output_path, original_image)
    print(f"Predictions saved to {output_path}")

# Test ID, change this to match your testing image
test_id = 288   # Example usage
# Model ID, change this to match your testing model
ba = 0.89       # Best model accuracy threshold
bl = 0.0599     # Best model loss threshold

# Paths
model_path = f"/content/drive/My Drive/OCRTraining/PassportDataset/train/model/best_model_{ba}_{bl}.pth"
image_path = f"/content/drive/My Drive/OCRTraining/PassportDataset/test/images/vpassport_{test_id}.jpg"
output_path = f"/content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_passport/predicted_vpassport_{test_id}.jpg"

# Load Model and Device
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model = load_model(model_path, num_classes=10).to(device)

# Run Prediction and Visualization
visualize_predictions(image_path, model, device, output_path)
# Out:
# <ipython-input-4-4793063ac134>:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=map_location))
# nameid 347.2960205078125, 1330.955078125, 781.1043090820312, 1401.799560546875
# sex 623.9873657226562, 1158.076904296875, 749.3565673828125, 1197.85302734375
# pob 938.0919799804688, 1119.719482421875, 1088.7918701171875, 1166.02685546875
# dob 628.4304809570312, 1094.3599853515625, 802.179443359375, 1136.3515625
# cmnd 928.7145385742188, 1185.157958984375, 1056.8521728515625, 1221.48681640625
# nationality 940.6444702148438, 1055.2967529296875, 1229.8485107421875, 1106.7686767578125
# passportid 997.57763671875, 975.9032592773438, 1131.196044921875, 1016.792724609375
# passportid2 308.67071533203125, 1376.48876953125, 473.3555603027344, 1425.3828125
# Detected field for {'fullname'} is missing, please try again
# Predictions saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_passport/predicted_vpassport_288.jpg

# %% [markdown]
# # Import VietOCR dependency

# %%
# !pip install vietocr
# Out:
# Requirement already satisfied: vietocr in /usr/local/lib/python3.10/dist-packages (0.3.13)
# Requirement already satisfied: einops==0.2.0 in /usr/local/lib/python3.10/dist-packages (from vietocr) (0.2.0)
# Requirement already satisfied: gdown==4.4.0 in /usr/local/lib/python3.10/dist-packages (from vietocr) (4.4.0)
# Requirement already satisfied: prefetch-generator==1.0.1 in /usr/local/lib/python3.10/dist-packages (from vietocr) (1.0.1)
# Requirement already satisfied: imgaug==0.4.0 in /usr/local/lib/python3.10/dist-packages (from vietocr) (0.4.0)
# Requirement already satisfied: albumentations==1.4.2 in /usr/local/lib/python3.10/dist-packages (from vietocr) (1.4.2)
# Requirement already satisfied: lmdb>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from vietocr) (1.5.1)
# Requirement already satisfied: scikit-image>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from vietocr) (0.25.0)
# Requirement already satisfied: pillow==10.2.0 in /usr/local/lib/python3.10/dist-packages (from vietocr) (10.2.0)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.2->vietocr) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.2->vietocr) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.2->vietocr) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.2->vietocr) (4.12.2)
# Requirement already satisfied: scikit-learn>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.2->vietocr) (1.6.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.2->vietocr) (4.10.0.84)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->vietocr) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->vietocr) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->vietocr) (1.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->vietocr) (4.67.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->vietocr) (4.12.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->vietocr) (3.8.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->vietocr) (4.10.0.84)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->vietocr) (2.36.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->vietocr) (2.0.6)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->vietocr) (3.4.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->vietocr) (2024.12.12)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->vietocr) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->vietocr) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.2->vietocr) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.2->vietocr) (3.5.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown==4.4.0->vietocr) (2.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0->vietocr) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0->vietocr) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0->vietocr) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0->vietocr) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0->vietocr) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0->vietocr) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.4.0->vietocr) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.4.0->vietocr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.4.0->vietocr) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.4.0->vietocr) (2024.12.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.4.0->vietocr) (1.7.1)

# %% [markdown]
# # Custom Augmentor
# For Indian Passport Dataset

# %%
from vietocr.tool.config import Cfg
from vietocr.model.trainer import Trainer
from imgaug import augmenters as iaa
import numpy as np
from PIL import Image
import cv2

# Define Custom Augmentor
class MyAugmentor:
    def __init__(self):
        self.aug = iaa.Sequential([
            iaa.Affine(rotate=(-10, 10)),  # Small random rotations
            iaa.GaussianBlur(sigma=(0, 0.1)),  # Blur intensity reduced
            iaa.AdditiveGaussianNoise(scale=(0, 0.01 * 255)),  # Noise intensity lowered
        ])

    # Detect if image is rotated in any of the 90, 180 or 270 degrees
    def correct_orientation_cv2(self, img):
        gray = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2GRAY)
        _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
        edges = cv2.Canny(thresh, 50, 150)
        lines = cv2.HoughLines(edges, 1, np.pi / 180, 100)
        angles = []

        if lines is not None:
            for rho, theta in lines[:, 0]:
                angle = (theta * 180 / np.pi) % 180
                if 80 <= angle <= 100 or 260 <= angle <= 280:
                    angles.append(angle)

        if len(angles) > 0:
            avg_angle = np.mean(angles)
            if avg_angle > 90:
                avg_angle -= 180
            return avg_angle
        return 0

    def __call__(self, img):
        angle = self.correct_orientation_cv2(img)
        img = img.rotate(-angle, expand=True) if abs(angle) > 1 else img

        # Apply augmentations and return as PIL Image
        augmented = self.aug(image=np.array(img))  # Convert PIL to NumPy, apply augmentation
        return Image.fromarray(augmented)  # Convert back to PIL Image

# %% [markdown]
# # Crop Selective Fields and Annotate
# For Indian Passport Dataset and optional for Synthetic Dataset

# %%
import os
import json
import random
from PIL import Image

# File paths
dataset_path = "/content/drive/My Drive/OCRTraining/PassportDataset"
images_folder = os.path.join(dataset_path, "img")  # Path to the original images
annotation_path = os.path.join(dataset_path, "original_annotation/annotation.json")  # Bounding box annotation
extracted_annotation_path = os.path.join(dataset_path, "extract/annotation.txt")  # Text annotations
train_folder = os.path.join(dataset_path, "train/crops")
test_folder = os.path.join(dataset_path, "test/crops")

# Ensure output folders exist
os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# Load annotation.json
with open(annotation_path, "r") as f:
    annotation_data = json.load(f)

# Load extracted text annotations
with open(extracted_annotation_path, "r") as f:
    text_annotations = f.readlines()

# Map extracted annotations into a dictionary
# Format: {image_file: [firstname, lastname, dob, country, gender, cardnumber]}
text_annotation_map = {}
for line in text_annotations:
    parts = line.strip().split("\t")
    img_file = os.path.basename(parts[0])  # Extract only the image file name
    text_annotation_map[img_file] = parts[1:]

# Map category_id to field indices in text_annotation_map
category_map = {1: 0, 2: 1, 3: 2, 4: 3, 5: 4, 6: 5}  # Maps category_id to the correct index in text_annotation_map

# Split images into train and test
def split_images(annotation_data, train_ratio=0.8):
    images = annotation_data["images"]
    annotations = annotation_data["annotations"]

    # Shuffle and split the data
    random.shuffle(images)
    split_idx = int(len(images) * train_ratio)
    train_images = images[:split_idx]
    test_images = images[split_idx:]

    # Get corresponding annotations
    train_ids = {img["id"] for img in train_images}
    train_annotations = [anno for anno in annotations if anno["image_id"] in train_ids]
    test_annotations = [anno for anno in annotations if anno["image_id"] not in train_ids]

    return train_images, train_annotations, test_images, test_annotations

# Crop and save fields from images
def crop_and_save_fields(images, annotations, output_folder, category_map, text_annotation_map):
    for anno in annotations:
        image_id = anno["image_id"]
        category_id = anno["category_id"]
        bbox = anno["bbox"]  # [x, y, width, height]

        # Get the corresponding image file
        image_file = next((img["file_name"] for img in images if img["id"] == image_id), None)
        if image_file:
            img_path = os.path.join(images_folder, image_file)
            if os.path.exists(img_path):
                # Open and crop the image
                img = Image.open(img_path)
                cropped = img.crop((bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1] + bbox[3]))

                # Check if category_id exists in category_map
                field_name = next((key for key, val in category_map.items() if val == category_id), None)
                if not field_name:
                    print(f"Warning: category_id {category_id} not found in category_map.")
                    continue  # Skip this annotation

                # Save cropped image
                cropped_img_path = os.path.join(output_folder, f"{image_id}_{field_name}.jpg")
                cropped.save(cropped_img_path)

                # Save the label using the extracted annotation
                if image_file in text_annotation_map:
                    label = text_annotation_map[image_file][category_map[category_id]]
                else:
                    label = "N/A"  # Default to N/A if no matching annotation found

                label_path = cropped_img_path.replace(".jpg", ".txt")
                with open(label_path, "w") as f:
                    f.write(label)

# Split the data
train_images, train_annotations, test_images, test_annotations = split_images(annotation_data)

# Crop and save for train and test
crop_and_save_fields(train_images, train_annotations, train_folder, category_map, text_annotation_map)
crop_and_save_fields(test_images, test_annotations, test_folder, category_map, text_annotation_map)

print("Cropping and Annotation complete!")
# Out:
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Warning: category_id 6 not found in category_map.
# Cropping and Annotation complete!

# %% [markdown]
# # GPU Usage on Google Collab

# %%
# Optional: Check if device/VM have GPU (for cuda)
# CHECK GPU USAGE CAPABILITY
import torch

# # Check if GPU is available and set the device
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') # If cuda is not available means that we are using CPU
# print(f"Using {device} for training")

if torch.cuda.is_available():
  print(f"GPU: {torch.cuda.get_device_name(0)} is available")
else:
  print("Run on CPU ONLY")

# On Google Collab, make sure to change runtime to GPU in advance
# Out:
# GPU: Tesla T4 is available

# %% [markdown]
# # Train Dataset with VietOCR
# For Indian Passport Dataset

# %%
from vietocr.tool.config import Cfg
from vietocr.model.trainer import Trainer
from imgaug import augmenters as iaa
import numpy as np
from PIL import Image
import cv2

# Configuration for the Model
config = Cfg.load_config_from_name('vgg_transformer')
'''
Summary of chosen config model:

| Feature                         | **vgg_transformer**                      | **vgg_seq2seq**                   |
|---------------------------------|------------------------------------------|-----------------------------------|
| **Decoder Type**                | Transformer                              | Seq2Seq with LSTM/GRU             |
| **Speed**                       | Slower on short text, faster on long text| Faster on short text              |
| **Accuracy**                    | Higher for longer text and complex data  | Slightly lower for long sequences |
| **Resource Usage**              | High (Memory, GPU)                       | Lower (Memory, GPU)               |
| **Best for**                    | Long text, complex sequences             | Short text, limited hardware      |
'''

# Update dataset parameters
dataset_params = {
    'name': 'passport',  # Dataset name
    'data_root': '/content/drive/My Drive/OCRTraining/PassportDataset',  # Base folder
    'train_annotation': 'train/train_annotation.txt',  # Train annotation file
    'valid_annotation': 'test/test_annotation.txt'  # Validation annotation file
}

# Update training parameters
params = {
    'print_every': 100,  # Print loss every 100 iterations
    'valid_every': 500,  # Validate every 500 iterations
    'iters': 5000,  # Number of training iterations
    'export': '/content/drive/My Drive/OCRTraining/PassportDataset/weights/passportocr.pth',  # Path to save weights
    'metrics': 20  # Number of test samples used for evaluation
}

# Update configurations
config['trainer'].update(params)
config['dataset'].update(dataset_params)
config['device'] = 'cpu'  # Use GPU if available, change to 'cpu' otherwise

# Initialize Trainer with Custom Augmentor
trainer = Trainer(config, pretrained=True, augmentor=MyAugmentor())

# Visualize dataset (optional)
trainer.visualize_dataset()

# Train the model
trainer.train()

# Save final configuration
trainer.config.save('/content/drive/My Drive/OCRTraining/PassportDataset/config.yml')
# Out:
# 18533it [00:15, 1166.24it/s]
# /usr/local/lib/python3.10/dist-packages/vietocr/model/trainer.py:278: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(filename, map_location=torch.device(self.device))
# Create train_passport:   0%|                                                 | 0/80 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-3804ca519d7d> in <cell line: 45>()
#      43
#      44 # Initialize Trainer with Custom Augmentor
# ---> 45 trainer = Trainer(config, pretrained=True, augmentor=MyAugmentor())
#      46
#      47 # Visualize dataset (optional)
#
# /usr/local/lib/python3.10/dist-packages/vietocr/model/trainer.py in __init__(self, config, pretrained, augmentor)
#      76             transforms =  augmentor
#      77
# ---> 78         self.train_gen = self.data_gen('train_{}'.format(self.dataset_name),
#      79                 self.data_root, self.train_annotation, self.masked_language_model, transform=transforms)
#      80         if self.valid_annotation:
#
# /usr/local/lib/python3.10/dist-packages/vietocr/model/trainer.py in data_gen(self, lmdb_path, data_root, annotation, masked_language_model, transform)
#     308
#     309     def data_gen(self, lmdb_path, data_root, annotation, masked_language_model=True, transform=None):
# --> 310         dataset = OCRDataset(lmdb_path=lmdb_path,
#     311                 root_dir=data_root, annotation_path=annotation,
#     312                 vocab=self.vocab, transform=transform,
#
# /usr/local/lib/python3.10/dist-packages/vietocr/loader/dataloader.py in __init__(self, lmdb_path, root_dir, annotation_path, vocab, image_height, image_min_width, image_max_width, transform)
#      37             sys.stdout.flush()
#      38         else:
# ---> 39             createDataset(self.lmdb_path, root_dir, annotation_path)
#      40
#      41         self.env = lmdb.open(
#
# /usr/local/lib/python3.10/dist-packages/vietocr/tool/create_dataset.py in createDataset(outputPath, root_dir, annotation_path)
#      52     pbar = tqdm(range(nSamples), ncols = 100, desc='Create {}'.format(outputPath))
#      53     for i in pbar:
# ---> 54         imageFile, label = annotations[i]
#      55         imagePath = os.path.join(root_dir, imageFile)
#      56
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# # Predict Dataset with VietOCR
# For Synthetic Dataset

# %% [markdown]
# - We use pre-trained vgg_transformer model from VietOCR for this task.
# - Pre-trained model already sustainable for text recognisation.
# - For manual training with text detection, review the methods of:
#   - Applying custom augumentor.
#   - Crop and annotate fields.
#   - Train with cropped fields from the Indian Dataset

# %%
import os
import torch
import cv2
import json
import numpy as np
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.transforms import functional as F
from vietocr.tool.predictor import Predictor
from vietocr.tool.config import Cfg

# Class Mapping
classes = {
    0: "fullname",
    1: "nationality",
    2: "dob",
    3: "sex",
    4: "pob",
    5: "cmnd",
    6: "passportid",
    7: "nameid",
    8: "passportid2"
}

# Load Faster R-CNN Model
def load_model(model_path, num_classes):
    """
    Load a Faster R-CNN model with a custom number of classes and weights.
    """
    model = fasterrcnn_resnet50_fpn(pretrained=False)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    map_location = torch.device('cpu') if not torch.cuda.is_available() else None
    model.load_state_dict(torch.load(model_path, map_location=map_location))
    model.eval()
    return model

# Load VietOCR
def load_vietocr_model():
    """
    Load the VietOCR model for text recognition.
    """
    config = Cfg.load_config_from_name('vgg_transformer')
    # Use either vgg_transformer or vgg_seq2seq, statistic comparision can be found in the above note block
    config['weights'] = ocr_model_weights_path

    config['device'] = 'cuda' if torch.cuda.is_available() else 'cpu'
    config['predictor']['beamsearch'] = False
    return Predictor(config)

# Read Text Using VietOCR
def read_text_with_vietocr(image, model):
    """
    Use VietOCR to read text from an image.
    """
    from PIL import Image
    pil_image = Image.fromarray(image)
    text = model.predict(pil_image)
    return text

# Process Bounding Boxes
def process_bbox_with_vietocr(image, model, bbox, field_name):
    """
    Extract the region of interest (ROI) from the image, adjust offsets for 'pob' and 'cmnd', and recognize text.
    """
    x_min, y_min, x_max, y_max = map(int, bbox)

    # Expand bbox for specific fields
    if field_name in ['pob', 'cmnd']:
        offset = 20  # Adjust offset as needed
        x_min = max(0, x_min - offset)
        y_min = max(0, y_min - offset)
        x_max = min(image.shape[1], x_max + offset)
        y_max = min(image.shape[0], y_max + offset)

    roi = image[y_min:y_max, x_min:x_max]
    return read_text_with_vietocr(roi, model)

# Detect and Extract Text
def detect_and_extract_text(image_path, detection_model, ocr_model, output_json_path):
    """
    Detect fields in an image, extract text using VietOCR, and save results in a JSON file.
    """
    # Load the image
    image = cv2.imread(image_path)
    original_image = image.copy()
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    tensor_image = F.to_tensor(image).unsqueeze(0).to(device)

    # Make predictions
    with torch.no_grad():
        predictions = detection_model(tensor_image)[0]

    boxes = predictions['boxes'].cpu().numpy()
    labels = predictions['labels'].cpu().numpy()
    scores = predictions['scores'].cpu().numpy()

    detected_classes = set()
    result = {}

    for box, label, score in zip(boxes, labels, scores):
        if score < 0.5:  # Confidence threshold
            continue
        class_name = classes[label]
        detected_classes.add(class_name)

        # Extract text with VietOCR
        text = process_bbox_with_vietocr(original_image, ocr_model, box, class_name)
        result[class_name] = text
        print(f"Extracted {class_name}: {text}")

    # Check for missing classes
    missing_classes = set(classes.values()) - detected_classes
    if missing_classes:
        print(f"Detected field for {missing_classes} is missing, please try again")

    # Save result to JSON
    with open(output_json_path, "w") as json_file:
        json.dump(result, json_file, indent=4)
    print(f"Text results saved to {output_json_path}")

# Paths
test_images_dir = "/content/drive/My Drive/OCRTraining/PassportDataset/test/images/"
output_text_dir = "/content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/"
os.makedirs(output_text_dir, exist_ok=True)

# Model Paths
detection_model_path = "/content/drive/My Drive/OCRTraining/PassportDataset/train/model/best_model_0.89_0.0599.pth"
ocr_model_weights_path = "/content/drive/My Drive/OCRTraining/PassportDataset/train/model/text_detection_weight.pth"  # Path to VietOCR weights

'''
If using pre-trained model, download from here:
https://vocr.vn/data/vietocr/vgg_transformer.pth
'''

# Load Models
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
detection_model = load_model(detection_model_path, num_classes=10).to(device)
ocr_model = load_vietocr_model()

# Process All Test Images
for image_name in os.listdir(test_images_dir):
    if image_name.endswith((".jpg", ".jpeg", ".png")):  # Supported image formats
        print(f"Processing {image_name}...")
        image_path = os.path.join(test_images_dir, image_name)
        output_json_path = os.path.join(output_text_dir, f"{os.path.splitext(image_name)[0]}.json")
        detect_and_extract_text(image_path, detection_model, ocr_model, output_json_path)
# Out:
# <ipython-input-11-5fb0b03019d5>:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=map_location))
# Processing vpassport_1805.jpg...
# Extracted nameid: 03100101001960
# Extracted dob: GI33/11/161
# Extracted sex: Nam
# Extracted passportid: Y53H69%
# Extracted cmnd: Construction
# Extracted pob: Stransform
# Extracted nationality: Nơi sinh/Phám tịch
# Extracted passportid2: YS316034
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1805.json
# Processing vpassport_2978.jpg...
# Extracted dob: 15/06/2002
# Extracted nationality: 0360000888000
# Extracted nameid: Constructionalists
# Extracted pob: RECONTONISTS
# Extracted passportid: W9455324
# Extracted sex: Nam/M
# Extracted cmnd: GROUNDING
# Extracted passportid2: WOASS332A
# Extracted sex: Dateoff
# Extracted dob: Sextailing
# Extracted nationality: 035324
# Extracted passportid: DICORVIET
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2978.json
# Processing vpassport_1743.jpg...
# Extracted pob: 07480g61,000
# Extracted dob: 2/10/134
# Extracted nationality: CHÉCOGẦN
# Extracted nameid: VNMÔVOloũaăupđời
# Extracted cmnd: 1201311
# Extracted sex: Nam/M
# Extracted passportid2: CH2550433
# Extracted passportid: HOSSOLSA
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1743.json
# Processing vpassport_163.jpg...
# Extracted cmnd: Discomminate
# Extracted sex: Giới Minh Sơn
# Extracted pob: Commonstruction
# Extracted passportid: CHOCKSIST
# Extracted nationality: Commissional
# Extracted dob: Nguyễn Theo
# Extracted nameid: MISCONTROMINATIONS
# Extracted passportid2: ANGHYSISTIC
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_163.json
# Processing vpassport_211.jpg...
# Extracted pob: mexascroocons
# Extracted dob: 0/02/ma
# Extracted nameid: VNHÔI VÀILLẦNY
# Extracted nationality: TRAOGOM
# Extracted passportid: semazan
# Extracted sex: Nam/M
# Extracted cmnd: 10621013
# Extracted passportid2: SWIS291
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_211.json
# Processing vpassport_280.jpg...
# Extracted cmnd: spreaces
# Extracted pob: DEMAGEOUS
# Extracted nameid: INTERMINONORIACIOUSNESS
# Extracted dob: Ng1/02/1985
# Extracted nationality: TRUYỀU XÔI TẦN THỊ THỊ
# Extracted passportid2: RA3A6655
# Extracted sex: Nữ
# Extracted passportid: BA3466550
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_280.json
# Processing vpassport_67.jpg...
# Extracted nameid: VNHQUẢOSOÁTĂQYÁ
# Extracted nationality: BÙI ÁONẬP
# Extracted dob: 12/01/ms
# Extracted pob: CONDIOSONTOPAL
# Extracted passportid: HALEOZ3O
# Extracted sex: Nam/M
# Extracted cmnd: 1553305510
# Extracted passportid2: H3480270
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_67.json
# Processing vpassport_2513.jpg...
# Extracted dob: 25/10/2006
# Extracted pob: OBDESOVANEIONS
# Extracted nationality: 038000000099
# Extracted nameid: VNIMÔDIPOCỘDẢOSP6
# Extracted sex: NB/F
# Extracted passportid: 036320374
# Extracted cmnd: 55%moss
# Extracted passportid2: 0376
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2513.json
# Processing vpassport_1492.jpg...
# Extracted pob: TOORYAMILIOE
# Extracted nationality: 036000000032
# Extracted nameid: VNMFJULYẠGELYZES
# Extracted dob: 30/06/1978
# Extracted cmnd: 474868081
# Extracted sex: Nữ
# Extracted passportid: C88284186
# Extracted passportid2: 08828418
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1492.json
# Processing vpassport_2839.jpg...
# Extracted dob: 10/106
# Extracted sex: NB/F
# Extracted nationality: LĐẤY GƠ
# Extracted nameid: VNHỎOĂVRRBIÁQAẮC
# Extracted passportid: commons
# Extracted pob: OVERBUTTERBRAGGED
# Extracted cmnd: 2003ward
# Extracted passportid2: CISOLOGS
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2839.json
# Processing vpassport_2434.jpg...
# Extracted nameid: VNMHẪU YẠAHÂUT
# Extracted passportid: E9706960
# Extracted dob: 24/10/1970
# Extracted pob: EAGETOIDS
# Extracted sex: Nữ
# Extracted cmnd: 405245522
# Extracted nationality: 051200000009
# Extracted passportid2: E9706960
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2434.json
# Processing vpassport_2028.jpg...
# Extracted pob: VÔY IOMIA THU
# Extracted dob: 14/03/1977
# Extracted nameid: VNMỸ ẹật ủệ ụy zổlês
# Extracted cmnd: 822689022
# Extracted sex: Nữ
# Extracted passportid: 024318550
# Extracted nationality: 01686014
# Extracted passportid2: 22431855
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2028.json
# Processing vpassport_2632.jpg...
# Extracted dob: Sex
# Extracted cmnd: aucosophically
# Extracted sex: Dateofies
# Extracted passportid: Va488706
# Extracted nameid: 145m28
# Extracted pob: 0001000000
# Extracted cmnd: oncorant
# Extracted sex: NGUYỄN THỊ THỊ THỊ HOÀNG
# Extracted dob: 06/10/1973
# Extracted passportid2: 03100000001
# Extracted nationality: 038706 KMN
# Extracted nameid: 1
# Extracted passportid: RECORVIES
# Extracted nationality: 03600000009
# Extracted pob: MOANTHWORK
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2632.json
# Processing vpassport_1505.jpg...
# Extracted pob: BONKENECOOMAGO
# Extracted sex: Nữ/F
# Extracted dob: 25/03/1967
# Extracted nationality: Năn Biên
# Extracted nameid: VNMUỆ
# Extracted cmnd: 03703212
# Extracted passportid: V14333304
# Extracted passportid2: VU433386
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1505.json
# Processing vpassport_2739.jpg...
# Extracted dob: Ngày sinh trong
# Extracted sex: Gianamitic
# Extracted cmnd: Stransforming
# Extracted pob: CONTRACTIONALISTS
# Extracted nationality: 03101994
# Extracted nameid: PHOTOCONOUSNESS
# Extracted passportid: 6 ho ession
# Extracted passportid2: CONSUMING
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2739.json
# Processing vpassport_325.jpg...
# Extracted nameid: 039198100199
# Extracted dob: sex
# Extracted pob: Phường
# Extracted nationality: 06298500
# Extracted sex: pateofically
# Extracted cmnd: Anticeoffinism
# Extracted passportid: DICOFFED
# Extracted passportid2: 0360000000099
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_325.json
# Processing vpassport_2743.jpg...
# Extracted nameid: VNMỜOèiidgodơik
# Extracted dob: 0/12/1983
# Extracted sex: Nữ
# Extracted nationality: Xào diễn
# Extracted pob: Tuyến Quan Trong Trong
# Extracted cmnd: 0340125540ver
# Extracted passportid: 03404727
# Extracted passportid2: 0340727
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2743.json
# Processing vpassport_2844.jpg...
# Extracted pob: letebroulude
# Extracted dob: 19/02/1964
# Extracted sex: Nam/M
# Extracted cmnd: 721395229
# Extracted nameid: VNMTỢQÊ??YỤTỸẠI
# Extracted nationality: SỬ EAJƯV
# Extracted passportid: 015383576
# Extracted passportid2: D1538357
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2844.json
# Processing vpassport_2576.jpg...
# Extracted nameid: MISVIROMENTCAMBMATICALLY
# Extracted dob: N31/06/1962
# Extracted pob: Eusovania
# Extracted cmnd: 30156232;
# Extracted nationality: Ư0000àilA
# Extracted sex: Nam/M
# Extracted passportid2: V8148179
# Extracted passportid: V81481794
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2576.json
# Processing vpassport_834.jpg...
# Extracted cmnd: 290447868
# Extracted nameid: VNMỨA TOVREỞỐỦVS
# Extracted nationality: 036000000002
# Extracted dob: 30/06/1978
# Extracted sex: Nữ
# Extracted pob: Autocaoxey
# Extracted passportid: H14046014
# Extracted passportid2: H1404601
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_834.json
# Processing vpassport_1012.jpg...
# Extracted dob: Ngày 12/1998
# Extracted nameid: COMMUNICATIONALISTS
# Extracted passportid: GAB9A3980
# Extracted nationality: ĐEUTRONING
# Extracted cmnd: 2602ASS00
# Extracted sex: GNam/M
# Extracted pob: moeoarching
# Extracted passportid2: GA894398
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1012.json
# Processing vpassport_831.jpg...
# Extracted dob: 26/09/2000
# Extracted nationality: 0000000001012000
# Extracted nameid: VNMƯỚU TẾNÊ .AỎ
# Extracted pob: CHIẾU VĂN HOÀNG
# Extracted passportid: 03203479
# Extracted sex: Nam/M
# Extracted cmnd: 112463038
# Extracted passportid2: N3203629
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_831.json
# Processing vpassport_73.jpg...
# Extracted nameid: WHOGEOEASÁPHIC
# Extracted sex: Nam/M
# Extracted pob: Chankering
# Extracted dob: 05/03/1987
# Extracted passportid: H1B87052
# Extracted passportid2: H1387052
# Extracted nationality: 03800000388
# Extracted cmnd: commensional
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_73.json
# Processing vpassport_2074.jpg...
# Extracted pob: CASAAMYLONS
# Extracted nameid: VNMÉHYỘKỨUÀ???);
# Extracted sex: Nam/M
# Extracted nationality: OZEYÁỨAA
# Extracted passportid: 132998281
# Extracted dob: 29/09/1990
# Extracted cmnd: 433863451
# Extracted passportid2: 13299828
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2074.json
# Processing vpassport_461.jpg...
# Extracted sex: Nam/M
# Extracted nameid: WHEN VEREURUE (SM2RANG)
# Extracted dob: 03/03/2003
# Extracted cmnd: Sociousness
# Extracted passportid: 03301000
# Extracted passportid2: 03703304
# Extracted pob: Markingstrand
# Extracted nationality: PHÓ THỊ THỊ THUYỀN
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_461.json
# Processing vpassport_922.jpg...
# Extracted pob: JUGGIENHUSE
# Extracted nameid: VNMQAÍ CÂLIÀ ỮỜĂQ
# Extracted dob: 08/10/1978
# Extracted sex: Nam/M
# Extracted nationality: jờyióhộ3
# Extracted cmnd: 962838693
# Extracted passportid2: W5203308
# Extracted passportid: 052033088
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_922.json
# Processing vpassport_237.jpg...
# Extracted nameid: 0360000000980
# Extracted sex: NĐ/F
# Extracted dob: 25/0V/1980
# Extracted pob: convolute
# Extracted passportid: S259404
# Extracted cmnd: 039850201093
# Extracted nationality: GASHIOU
# Extracted passportid2: 8259401
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_237.json
# Processing vpassport_2013.jpg...
# Extracted dob: Giải Thị Da
# Extracted nationality: 036000000099
# Extracted nameid: Constructionalists
# Extracted sex: NAM
# Extracted passportid: DIBHE3
# Extracted pob: commonstributions
# Extracted cmnd: 03100000001
# Extracted passportid2: DAINES
# Extracted nameid: 0300000145m200002
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2013.json
# Processing vpassport_453.jpg...
# Extracted dob: 22/01/1921
# Extracted nameid: VNMB3YFORIOỀTCHK
# Extracted passportid: 05233607
# Extracted pob: CONSPUTATIONALIZE
# Extracted cmnd: 05610012
# Extracted nationality: 0300000000000
# Extracted sex: Nam/M
# Extracted passportid2: 05378617
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_453.json
# Processing vpassport_2475.jpg...
# Extracted nameid: VNHẦY Ý YUÔHÊỔA ÔỞ
# Extracted nationality: VIÊM ĐÚC MIỀ
# Extracted dob: TR/OV100
# Extracted cmnd: 228881832
# Extracted sex: Nam/M
# Extracted passportid: K2137308
# Extracted pob: Absectroelessness
# Extracted passportid2: K2183708
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2475.json
# Processing vpassport_1412.jpg...
# Extracted pob: Sexoucatives
# Extracted dob: 13/10/1991
# Extracted sex: Nam/M
# Extracted nameid: VNMVMÊ ƠỞYÂỬI YẬỘ
# Extracted nationality: Ử/IÁÉY?É
# Extracted cmnd: 368885151
# Extracted passportid: M45904476
# Extracted passportid2: M4590447
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1412.json
# Processing vpassport_2716.jpg...
# Extracted pob: vulvônaetics
# Extracted cmnd: 984936415
# Extracted nationality: 0010000000022
# Extracted dob: 24/10/1970
# Extracted nameid: VNMXỨPOVÀEUXGKRS
# Extracted sex: Nữ
# Extracted passportid: 051329472
# Extracted passportid2: 05132947
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2716.json
# Processing vpassport_2542.jpg...
# Extracted dob: wextainer
# Extracted nameid: 0381001981072
# Extracted pob: phâu con
# Extracted nationality: 03890019890rt No Trans
# Extracted sex: pateofic
# Extracted cmnd: Avyen banh
# Extracted passportid: HOLICOFFIED
# Extracted passportid2: 0310000000099
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2542.json
# Processing vpassport_2310.jpg...
# Extracted pob: Lầu có Au?work
# Extracted nameid: VNMI ACATOAẠLẤPỜ
# Extracted sex: Nữ
# Extracted dob: 31/10/1996
# Extracted cmnd: 524803036
# Extracted nationality: HMÊU DÊQ
# Extracted passportid: 793326958
# Extracted passportid2: 79332695
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2310.json
# Processing vpassport_2297.jpg...
# Extracted nationality: 0eáẻ010w
# Extracted dob: 13/04/2000
# Extracted sex: Nữ
# Extracted nameid: VNMÁY VẤRPOWẮVĂE
# Extracted pob: compleynessing
# Extracted passportid: E210URBO
# Extracted cmnd: 9508111111
# Extracted passportid2: FRINES9
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2297.json
# Processing vpassport_1616.jpg...
# Extracted nameid: 1730411110060EA01A0002
# Extracted dob: 09/02/1965
# Extracted pob: sulmessiveness
# Extracted passportid: X9739413
# Extracted sex: Nữ
# Extracted cmnd: 3essasies
# Extracted nationality: Nơi sinh 7/0660000
# Extracted passportid2: X9739413
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1616.json
# Processing vpassport_1419.jpg...
# Extracted nameid: VNMỒMÔHAUSYẾO Ă?
# Extracted nationality: Y?quể ăo
# Extracted dob: 11/04/1981
# Extracted pob: GROVIEOCONNVANCE
# Extracted passportid: GU827585
# Extracted sex: Nữ
# Extracted passportid2: G4887585
# Extracted cmnd: 240842555
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1419.json
# Processing vpassport_501.jpg...
# Extracted pob: METOROACHYEROS
# Extracted dob: 07/10/1959
# Extracted nationality: TĐUỎIỄUÝ
# Extracted sex: Nam/M
# Extracted nameid: VNMULYÉOLÃM?ỆPIK
# Extracted passportid2: E8566817
# Extracted passportid: E354317
# Extracted cmnd: 03431837
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_501.json
# Processing vpassport_297.jpg...
# Extracted pob: Disassemblying
# Extracted dob: 03/0B/183R
# Extracted nameid: VNMUYIÔFXÂUÃIIÚC
# Extracted nationality: PHÒ XNÔ
# Extracted cmnd: 37024101
# Extracted sex: Nam/M
# Extracted passportid: 429021
# Extracted passportid2: 036290210
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_297.json
# Processing vpassport_2365.jpg...
# Extracted dob: 05/01/1994
# Extracted nationality: 0360000000030
# Extracted nameid: VNMỜỨATWJOPXEUỎ
# Extracted cmnd: INCULATION
# Extracted sex: Nam/M
# Extracted pob: Haumadroscations
# Extracted passportid: 07316110
# Extracted passportid2: 07316110
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2365.json
# Processing vpassport_27.jpg...
# Extracted nameid: CONTRANSECTASMONIC
# Extracted dob: Ngoy/07/2005
# Extracted sex: Nam/M
# Extracted pob: MISCONTRACTION
# Extracted nationality: 036000000099
# Extracted cmnd: Spoonsters
# Extracted passportid2: YS000456
# Extracted passportid: 15000656
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_27.json
# Processing vpassport_897.jpg...
# Extracted dob: 2/2/00
# Extracted nationality: 030000000099
# Extracted pob: VOTIOUSNESS
# Extracted nameid: VNMSÂY JAÃIÔEIẢ
# Extracted cmnd: 284185m6n
# Extracted sex: Nam/M
# Extracted passportid2: 1981
# Extracted passportid: H20201
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_897.json
# Processing vpassport_1282.jpg...
# Extracted pob: Precessionalists
# Extracted cmnd: Glession
# Extracted dob: 21/04/2000
# Extracted nationality: 03600000009
# Extracted passportid: Z65233339
# Extracted nameid: 030100000000196
# Extracted sex: Nữ
# Extracted passportid2: 26523539
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1282.json
# Processing vpassport_1065.jpg...
# Extracted nationality: 036000000099
# Extracted nameid: VNMZ?WỜNÔERÚĐTÊ
# Extracted dob: 21/09/1959
# Extracted sex: Nữ
# Extracted pob: OVERSONCULATION
# Extracted cmnd: 956198535
# Extracted passportid: NGU225300
# Extracted passportid2: NGU33582U
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1065.json
# Processing vpassport_1324.jpg...
# Extracted pob: sematacyxer
# Extracted dob: 16/01/1980
# Extracted nameid: VNMẠQ?NỆXÝ ẬT?Ử
# Extracted sex: Nữ
# Extracted nationality: 01ếgoeik
# Extracted cmnd: 237666435
# Extracted passportid: x55776896
# Extracted passportid2: x5577689
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1324.json
# Processing vpassport_711.jpg...
# Extracted sex: GIONALISTIC
# Extracted nameid: SUBSTRUCTIONALIZED
# Extracted dob: Ngày 52/2007
# Extracted nationality: 00119900000199
# Extracted pob: MISCONTRACTION
# Extracted passportid: 6 MOSSIONING
# Extracted cmnd: Construction
# Extracted passportid2: PRESISSIONAL
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_711.json
# Processing vpassport_1172.jpg...
# Extracted cmnd: 192638299
# Extracted pob: Accoauches
# Extracted dob: 29/01/1961
# Extracted nameid: VNMFIÓƯÌLÃOMèỘÀS
# Extracted passportid: 0015089950
# Extracted sex: Nữ
# Extracted nationality: TỢÒEEQUỤ
# Extracted passportid2: j1508995
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1172.json
# Processing vpassport_2671.jpg...
# Extracted cmnd: Constructive
# Extracted dob: Ngayễn 2000
# Extracted sex: Giói mà con
# Extracted nameid: CONTERMINIOUSNESS
# Extracted pob: CONTRANSITIONALISTS
# Extracted passportid: MOCQUENT
# Extracted nationality: commissed
# Extracted passportid2: PHOTOGRAPHIZING
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2671.json
# Processing vpassport_1406.jpg...
# Extracted pob: CALUCOUAUS
# Extracted cmnd: 190958484
# Extracted dob: 25/02/2004
# Extracted nameid: VNMEOẠI ÁỢIZFỮƠÍS
# Extracted sex: Nam/M
# Extracted nationality: 036000000039
# Extracted passportid: 076831564
# Extracted passportid2: 07683156
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1406.json
# Processing vpassport_2219.jpg...
# Extracted nameid: VNMÁO TỸ)ÒDĂO ỦÊỨC
# Extracted nationality: 00100038121CMR
# Extracted dob: 1/10/1991
# Extracted cmnd: 94611251
# Extracted passportid: K5410713
# Extracted pob: CONSUMPLETATORS
# Extracted sex: Nam/M
# Extracted passportid2: K5610743
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2219.json
# Processing vpassport_2512.jpg...
# Extracted dob: Sex
# Extracted nameid: 036195M281077
# Extracted pob: OUTSTONE
# Extracted nationality: 128440000001201
# Extracted cmnd: teaknothing
# Extracted sex: Dateofical
# Extracted passportid: PLICOFVILS
# Extracted passportid2: 0310000000990
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2512.json
# Processing vpassport_1798.jpg...
# Extracted dob: 15/11/2000
# Extracted cmnd: 982593443
# Extracted sex: Nam/M
# Extracted nameid: VNMÌPRỰÂY 2-6%C-
# Extracted nationality: 06ái Y?Dx
# Extracted pob: LUMBOOYAUD
# Extracted passportid: 026299973
# Extracted passportid2: 22629997
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1798.json
# Processing vpassport_2860.jpg...
# Extracted cmnd: 707232432
# Extracted pob: MAUAVAYIUM
# Extracted nameid: VNMYỦYẢAIWỞYẠTES
# Extracted nationality: CHỨ LÝ ASỰAE
# Extracted dob: 06/11/1996
# Extracted passportid: M610095TS
# Extracted sex: Nữ
# Extracted passportid2: M6100951
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_2860.json
# Processing vpassport_1023.jpg...
# Extracted nameid: 030100100000199
# Extracted dob: GIỜI/12/m3
# Extracted pob: virogenizers
# Extracted cmnd: 038000000099
# Extracted sex: Nam/H
# Extracted passportid: VATIIN23
# Extracted nationality: Nơi sinh/ Phó yết thị
# Extracted passportid2: WIJ9123
# Detected field for {'fullname'} is missing, please try again
# Text results saved to /content/drive/My Drive/OCRTraining/PassportDataset/test/predicted_text/vpassport_1023.json
# Processing vpassport_2505.jpg...

# %% [markdown]
# # Evaluate Result on Test Set
# For Indian Passport Dataset

# %%
from vietocr.tool.predictor import Predictor
from PIL import Image
import os

# Load the trained model and configuration
predictor = Predictor(config)

# Path to the test crops folder
test_crops_folder = '/content/drive/My Drive/OCRTraining/PassportDataset/test/crops'
test_images = [f for f in os.listdir(test_crops_folder) if f.endswith('.jpg')]

correct = 0
total = len(test_images)

for img_name in test_images:
    img_path = os.path.join(test_crops_folder, img_name)
    txt_path = img_path.replace('.jpg', '.txt')

    with open(txt_path, 'r') as f:
        ground_truth = f.read().strip()

    # Load the image using PIL
    image = Image.open(img_path)
    prediction = predictor.predict(image).strip()

    print(f"GT: {ground_truth}, Predicted: {prediction}")
    if prediction == ground_truth:
        correct += 1

# Accuracy per cent
accuracy = correct / total * 100
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# Model weight /tmp/vgg_transformer.pth exsits. Ignore download!
# GT: firstname, Predicted: cursier
# GT: lastname, Predicted: imm
# GT: dob, Predicted: 20/16/1131
# GT: country, Predicted: cuss
# GT: gender, Predicted: e
# GT: cardnumber, Predicted: 13463400
# GT: firstname, Predicted: I
# GT: lastname, Predicted: T
# GT: dob, Predicted:
# GT: country, Predicted: E
# GT: gender, Predicted: 7
# GT: cardnumber, Predicted:
# GT: firstname, Predicted: VIVHISON 474S
# GT: lastname, Predicted: 1NY3 80097H
# GT: dob, Predicted: 2861/50/20
# GT: country, Predicted: INVIGNI
# GT: gender, Predicted: w
# GT: cardnumber, Predicted: 160E1 79H
# GT: firstname, Predicted: hon12 91vaud
# GT: lastname, Predicted: nojhax
# GT: dob, Predicted: ocerysover
# GT: country, Predicted: NAIGNI
# GT: gender, Predicted: M
# GT: cardnumber, Predicted: revoearl
# GT: firstname, Predicted: CURVIO S1860
# GT: lastname, Predicted: canlen
# GT: dob, Predicted: 19/07/1990
# GT: country, Predicted: MOLAN
# GT: gender, Predicted: m
# GT: cardnumber, Predicted: 1440791
# GT: firstname, Predicted: hon12 ti3ujag
# GT: lastname, Predicted: Llahl
# GT: dob, Predicted: P8eryrovro
# GT: country, Predicted: NAIGWI
# GT: gender, Predicted: M
# GT: cardnumber, Predicted: SEVISETO
# GT: firstname, Predicted: 1
# GT: lastname, Predicted: 1
# GT: dob, Predicted:
# GT: country, Predicted:
# GT: gender, Predicted: 7
# GT: cardnumber, Predicted: e
# GT: firstname, Predicted: I Hon12 933gnadad 19
# GT: lastname, Predicted: uhona2
# GT: dob, Predicted: teeryson ro
# GT: country, Predicted: WAIGHT
# GT: gender, Predicted: m
# GT: cardnumber, Predicted: ootsofem
# GT: firstname, Predicted: X30NIMTV4
# GT: lastname, Predicted: th9n 1s
# GT: dob, Predicted: 7661790/61
# GT: country, Predicted: NVIGNI
# GT: gender, Predicted: 6
# GT: cardnumber, Predicted: 0910100819
# GT: firstname, Predicted: ZNAIN INDIGYS
# GT: lastname, Predicted: xvaow
# GT: dob, Predicted: 6861/01/10
# GT: country, Predicted: INVIGNI
# GT: gender, Predicted: w
# GT: cardnumber, Predicted: LEVISEOSH
# GT: firstname, Predicted: reasojinour sinch
# GT: lastname, Predicted: EA1010
# GT: dob, Predicted: 20/08/1991
# GT: country, Predicted: INDIAN
# GT: gender, Predicted: m
# GT: cardnumber, Predicted: H7362738
# GT: firstname, Predicted: ahnin2
# GT: lastname, Predicted: amrah2
# GT: dob, Predicted: 289rystAto
# GT: country, Predicted: WAIGHI
# GT: gender, Predicted: 1
# GT: cardnumber, Predicted: NEBOS8OMS
# GT: firstname, Predicted: SHIERA
# GT: lastname, Predicted: SEAGRA
# GT: dob, Predicted: 01/7201985
# GT: country, Predicted: INDIAN
# GT: gender, Predicted: 0
# GT: cardnumber, Predicted: 03 H0820537
# GT: firstname, Predicted:
# GT: lastname, Predicted:
# GT: dob, Predicted:
# GT: country, Predicted: 1
# GT: gender, Predicted: 7
# GT: cardnumber, Predicted: I
# GT: firstname, Predicted: 03310811V 7N9NVX
# GT: lastname, Predicted: 10VN V8
# GT: dob, Predicted: 9861/50/52
# GT: country, Predicted: nvigni
# GT: gender, Predicted: 1
# GT: cardnumber, Predicted: consector
# GT: firstname, Predicted: 18:1000/87
# GT: lastname, Predicted: 81860
# GT: dob, Predicted: 22/04/1096
# GT: country, Predicted: BIDIAN
# GT: gender, Predicted: n
# GT: cardnumber, Predicted: 19693722
# GT: lastname, Predicted: vingnovava
# GT: dob, Predicted: 6561/60/62
# GT: country, Predicted: NVIONI
# GT: firstname, Predicted: IN INHSNOT WHIM 711S
# GT: gender, Predicted: 1
# GT: cardnumber, Predicted: 79869E81
# GT: firstname, Predicted: T
# GT: lastname, Predicted: L
# GT: dob, Predicted: 1
# GT: country, Predicted:
# GT: gender, Predicted: F
# GT: cardnumber, Predicted: e
# GT: firstname, Predicted: 1
# GT: lastname, Predicted: 3
# GT: dob, Predicted: 019
# GT: country, Predicted: 1
# GT: gender, Predicted: 3
# GT: cardnumber, Predicted:
# GT: firstname, Predicted: 00106010 8184
# GT: lastname, Predicted: 6601
# GT: dob, Predicted: 00110371924
# GT: country, Predicted: DIOLAN
# GT: gender, Predicted: 0
# GT: cardnumber, Predicted: 12741120
# Test Accuracy: 0.00%

# %%
import matplotlib.pyplot as plt
from PIL import Image

test_sample = os.listdir(test_crops_folder)[:5]  # Load a few test samples
for img_name in test_sample:
    img_path = os.path.join(test_crops_folder, img_name)
    txt_path = img_path.replace('.jpg', '.txt')

    with open(txt_path, 'r') as f:
        label = f.read().strip()

    img = Image.open(img_path)
    plt.imshow(img)
    plt.title(f"Label: {label}")
    plt.show()

# %% [markdown]
# # Inference Post Training
# For Indian Passport Dataset

# %%
from vietocr.tool.predictor import Predictor
from vietocr.tool.config import Cfg
from PIL import Image
import cv2
import numpy as np

# Load the configuration and pretrained model
config = Cfg.load_config_from_file('/content/drive/My Drive/OCRTraining/PassportDataset/config.yml')
config['weights'] = '/content/drive/My Drive/OCRTraining/PassportDataset/weights/passportocr.pth'
config['device'] = 'cuda:0'

detector = Predictor(config)

# Function to correct orientation
def correct_orientation(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Detect skew/rotation using text region properties
    def find_orientation(img):
        # Threshold the image
        _, thresh = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

        # Detect edges
        edges = cv2.Canny(thresh, 50, 150)

        # Hough Line Transformation to detect lines
        lines = cv2.HoughLines(edges, 1, np.pi / 180, 100)
        angles = []

        if lines is not None:
            for rho, theta in lines[:, 0]:
                angle = (theta * 180 / np.pi) % 180  # Convert to degrees
                if 80 <= angle <= 100 or 260 <= angle <= 280:  # Horizontal lines
                    angles.append(angle)

        # Average detected angle
        if len(angles) > 0:
            avg_angle = np.mean(angles)
            if avg_angle > 90:  # Handle upside-down case
                avg_angle -= 180
            return avg_angle
        return 0  # No correction needed

    angle = find_orientation(img)
    print(f"Detected rotation angle: {angle}")

    # Correct the rotation if needed
    if abs(angle) > 1:  # Apply correction only for significant angles
        (h, w) = img.shape[:2]
        center = (w // 2, h // 2)
        rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
        corrected_img = cv2.warpAffine(img, rotation_matrix, (w, h), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REPLICATE)
        return Image.fromarray(corrected_img)  # Convert to PIL Image
    else:
        return Image.open(image_path)

# Correct orientation and perform OCR
img_path = '/content/drive/My Drive/OCRTraining/PassportDataset/test/crops/59_dob.jpg'
corrected_img = correct_orientation(img_path)

# Perform OCR
prediction = detector.predict(corrected_img, return_prob=True) # Use "return_prob=False" if don't want to show probability
print(f"Predicted Text: {prediction}")
# Out:
# Detected rotation angle: 0
# Predicted Text: ('dob', 0.9305401047070821)
